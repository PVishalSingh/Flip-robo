# %% [markdown]
# # ASSIGNMENT - 6 (Housing Project)

# %% [markdown]
# ## Punit Vishal Singh----> 22/8/22

# %% [markdown]
# ## Handle Test Data set

# %%
# Importing libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor

# %%
train_data=pd.read_csv("train.csv")
test_data=pd.read_csv("test.csv")

# %%
train_data
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     127         120       RL          NaN     4928   Pave   NaN      IR1
# 1     889          20       RL         95.0    15865   Pave   NaN      IR1
# 2     793          60       RL         92.0     9920   Pave   NaN      IR1
# 3     110          20       RL        105.0    11751   Pave   NaN      IR1
# 4     422          20       RL          NaN    16635   Pave   NaN      IR1
# ...   ...         ...      ...          ...      ...    ...   ...      ...
# 1163  289          20       RL          NaN     9819   Pave   NaN      IR1
# 1164  554          20       RL         67.0     8777   Pave   NaN      Reg
# 1165  196         160       RL         24.0     2280   Pave   NaN      Reg
# 1166   31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 1167  617          60       RL          NaN     7861   Pave   NaN      IR1
#
# ...

# %%
train_data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
train_data.shape
# Out:
# (1168, 81)

# %%
train_data.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
test_data.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# Length: 80, dtype: object

# %% [markdown]
# ## Checking Null Values

# %%
#check null values
test_data.isnull().sum()
# Out:
# Id                0
# MSSubClass        0
# MSZoning          0
# LotFrontage      45
# LotArea           0
#                  ..
# MiscVal           0
# MoSold            0
# YrSold            0
# SaleType          0
# SaleCondition     0
# Length: 80, dtype: int64

# %%
#check null values
train_data.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      214
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
train_data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1168.000000  1168.000000    954.00000    1168.000000  1168.000000
# mean    724.136130    56.767979     70.98847   10484.749144     6.104452
# std     416.159877    41.940650     24.82875    8957.442311     1.390153
# min       1.000000    20.000000     21.00000    1300.000000     1.000000
# 25%     360.500000    20.000000     60.00000    7621.500000     5.000000
# 50%     714.500000    50.000000     70.00000    9522.500000     6.000000
# 75%    1079.500000    70.000000     80.00000   11515.500000     7.000000
# max    1460.000000   190.000000    313.00000  164660.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1168.000000  1168.000000   1168.000000  1161.000000  1168.000000  ...
# mean      5.595890  1970.930651   1984.758562   102.310078   444.726027  ...
# std       1.124343    30.145255     20.785185   182.595606   462.664785  ...
# ...

# %% [markdown]
# ## Creating plots for our hypothesis variables:-

# %%
plt.scatter(train_data['LotFrontage'], train_data['SalePrice'])
plt.xlabel('LotFrontage',fontsize=14)
plt.ylabel('SalePrice', fontsize=14)
plt.show()

# %%
plt.bar(train_data['MSSubClass'], train_data['SalePrice'])
plt.xlabel('MSSubClass',fontsize=14)
plt.ylabel('SalePrice', fontsize=14)
plt.show()

# %%
plt.bar(train_data['MoSold'], train_data['SalePrice'])
plt.xlabel('MoSold',fontsize=14)
plt.ylabel('SalePrice', fontsize=14)
plt.show()

# %%
plt.bar(train_data['SaleCondition'], train_data['SalePrice'])
plt.xlabel('SaleCondition',fontsize=14)
plt.ylabel('SalePrice', fontsize=14)
plt.show()

# %%
plt.bar(train_data['SaleType'], train_data['SalePrice'])
plt.xlabel('SaleType',fontsize=14)
plt.ylabel('SalePrice', fontsize=14)
plt.show()

# %% [markdown]
# ## Creating Correlation Matrix

# %% [markdown]
# In order to have clear picture to understand how each variable is related to the target variable

# %%
corr_matrix = train_data.corr()


corr_matrix.style.background_gradient(cmap='RdYlGn')
# Out:
# <style type="text/css">
# #T_64b5a_row0_col0, #T_64b5a_row1_col1, #T_64b5a_row2_col2, #T_64b5a_row3_col3, #T_64b5a_row4_col4, #T_64b5a_row5_col5, #T_64b5a_row6_col6, #T_64b5a_row7_col7, #T_64b5a_row8_col8, #T_64b5a_row9_col9, #T_64b5a_row10_col10, #T_64b5a_row11_col11, #T_64b5a_row12_col12, #T_64b5a_row13_col13, #T_64b5a_row14_col14, #T_64b5a_row15_col15, #T_64b5a_row16_col16, #T_64b5a_row17_col17, #T_64b5a_row18_col18, #T_64b5a_row19_col19, #T_64b5a_row20_col20, #T_64b5a_row21_col21, #T_64b5a_row22_col22, #T_64b5a_row23_col23, #T_64b5a_row24_col24, #T_64b5a_row25_col25, #T_64b5a_row26_col26, #T_64b5a_row27_col27, #T_64b5a_row28_col28, #T_64b5a_row29_col29, #T_64b5a_row30_col30, #T_64b5a_row31_col31, #T_64b5a_row32_col32, #T_64b5a_row33_col33, #T_64b5a_row34_col34, #T_64b5a_row35_col35, #T_64b5a_row36_col36, #T_64b5a_row37_col37 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# ## Model Fitting

# %%
x_train = train_data[['LotFrontage','MSSubClass','BedroomAbvGr']]
y_train = train_data['SalePrice']

model1 = LinearRegression()
score1 = cross_val_score(model1,x_train, y_train, cv=10, scoring='r2')
score2 = cross_val_score(model1,x_train, y_train, cv=10, scoring='neg_root_mean_squared_error')
print('The rmse value is',np.abs(score2.mean()))
print('The r square value is', score1.mean())
# Out:
# The rmse value is nan
# The r square value is nan
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 10 fits failed out of a total of 10.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
# ...

# %%
x_train = train_data[['MSSubClass','LotFrontage','LotArea','OverallQual','OverallCond']]
y_train = train_data['SalePrice']

model2 = LinearRegression()
score1 = cross_val_score(model2,x_train, y_train, cv=10, scoring='r2')
score2 = cross_val_score(model2,x_train, y_train, cv=10, scoring='neg_root_mean_squared_error')
print('The rmse value is',np.abs(score2.mean()))
print('The r square value is', score1.mean())
# Out:
# The rmse value is nan
# The r square value is nan
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 10 fits failed out of a total of 10.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
# ...

# %%
x_train = train_data[['MSSubClass','LotFrontage','LotArea','OverallQual','OverallCond','YearBuilt','BedroomAbvGr','YearRemodAdd','MasVnrArea','BsmtFinSF1','WoodDeckSF','OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch','PoolArea','MiscVal']]
y_train = train_data['SalePrice']

model3 = LinearRegression()
score1 = cross_val_score(model3,x_train, y_train, cv=10, scoring='r2')
score2 = cross_val_score(model3,x_train, y_train, cv=10, scoring='neg_root_mean_squared_error')
print('The rmse value is',np.abs(score2.mean()))
print('The r square value is', score1.mean())
# Out:
# The rmse value is nan
# The r square value is nan
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 10 fits failed out of a total of 10.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
# ...

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Log Transformation

# %%
train_data.hist(column='SalePrice')
# Out:
# array([[<AxesSubplot:title={'center':'SalePrice'}>]], dtype=object)

# %%
train_data['logged SalePrice']=np.log(train_data.SalePrice)
train_data.head()
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  127         120       RL          NaN     4928   Pave   NaN      IR1
# 1  889          20       RL         95.0    15865   Pave   NaN      IR1
# 2  793          60       RL         92.0     9920   Pave   NaN      IR1
# 3  110          20       RL        105.0    11751   Pave   NaN      IR1
# 4  422          20       RL          NaN    16635   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolQC  Fence MiscFeature MiscVal MoSold YrSold  \
# 0         Lvl    AllPub  ...    NaN    NaN         NaN       0      2   2007
# 1         Lvl    AllPub  ...    NaN    NaN         NaN       0     10   2007
# 2         Lvl    AllPub  ...    NaN    NaN         NaN       0      6   2007
# 3         Lvl    AllPub  ...    NaN  MnPrv         NaN       0      1   2010
# 4         Lvl    AllPub  ...    NaN    NaN         NaN       0      6   2009
#
#   SaleType  SaleCondition  SalePrice  logged SalePrice
# ...

# %%
train_data.hist(column='logged SalePrice')
# Out:
# array([[<AxesSubplot:title={'center':'logged SalePrice'}>]], dtype=object)

# %%
sns.displot(train_data['LotFrontage'])

# %%
x_train = train_data[['MSSubClass','LotFrontage','LotArea','OverallQual','OverallCond','YearBuilt','BedroomAbvGr','YearRemodAdd','MasVnrArea','BsmtFinSF1','WoodDeckSF','OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch','PoolArea','MiscVal']]
y_train = train_data['logged SalePrice']

model4 = LinearRegression()
score1 = cross_val_score(model4,x_train, y_train, cv=10, scoring='r2')
score2 = cross_val_score(model4,x_train, y_train, cv=10, scoring='neg_root_mean_squared_error')
print('The rmse value is',np.abs(score2.mean()))
print('The r square value is', score1.mean())
# Out:
# The rmse value is nan
# The r square value is nan
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 10 fits failed out of a total of 10.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
# ...

# %% [markdown]
# ## Creating a new variable

# %% [raw]
# Creating two new variables from date :> Year of selling and month of selling

# %%
train_data.head()
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  127         120       RL          NaN     4928   Pave   NaN      IR1
# 1  889          20       RL         95.0    15865   Pave   NaN      IR1
# 2  793          60       RL         92.0     9920   Pave   NaN      IR1
# 3  110          20       RL        105.0    11751   Pave   NaN      IR1
# 4  422          20       RL          NaN    16635   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolQC  Fence MiscFeature MiscVal MoSold YrSold  \
# 0         Lvl    AllPub  ...    NaN    NaN         NaN       0      2   2007
# 1         Lvl    AllPub  ...    NaN    NaN         NaN       0     10   2007
# 2         Lvl    AllPub  ...    NaN    NaN         NaN       0      6   2007
# 3         Lvl    AllPub  ...    NaN  MnPrv         NaN       0      1   2010
# 4         Lvl    AllPub  ...    NaN    NaN         NaN       0      6   2009
#
#   SaleType  SaleCondition  SalePrice  logged SalePrice
# ...

# %%
train_data['YrSold'] = pd.DatetimeIndex(train_data['MoSold']).year
train_data[['YrSold']]
# Out:
#       YrSold
# 0       1970
# 1       1970
# 2       1970
# 3       1970
# 4       1970
# ...      ...
# 1163    1970
# 1164    1970
# 1165    1970
# 1166    1970
# 1167    1970
#
# [1168 rows x 1 columns]

# %%
x_train = train_data[['MSSubClass','LotFrontage','LotArea','OverallQual','OverallCond','YearBuilt','BedroomAbvGr','YearRemodAdd','MasVnrArea','BsmtFinSF1','WoodDeckSF','OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch','PoolArea','MiscVal']]
y_train = train_data['logged SalePrice']

model5 = LinearRegression()
score1 = cross_val_score(model5,x_train, y_train, cv=10, scoring='r2')
score2 = cross_val_score(model5,x_train, y_train, cv=10, scoring='neg_root_mean_squared_error')
print('The rmse value is',np.abs(score2.mean()))
print('The r square value is', score1.mean())
# Out:
# The rmse value is nan
# The r square value is nan
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 10 fits failed out of a total of 10.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
# ...

# %%
train_data['Alley'] = train_data['YrSold'] - train_data.SaleType
train_data.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\anaconda file\lib\site-packages\pandas\core\ops\array_ops.py:163, in _na_arithmetic_op(left, right, op, is_cmp)
#     162 try:
# --> 163     result = func(left, right)
#     164 except TypeError:
#
# File ~\anaconda3\anaconda file\lib\site-packages\pandas\core\computation\expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File ~\anaconda3\anaconda file\lib\site-packages\pandas\core\computation\expressions.py:128, in _evaluate_numexpr(op, op_str, a, b)
#     127 if result is None:
# --> 128     result = _evaluate_standard(op, op_str, a, b)
#     130 return result
#
# ...
