# %% [markdown]
# # Punit Vishal Singh----> 22/8/22

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load Data Set

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

print("Shape of train: ", train.shape)
print("Shape of test: ", test.shape)
# Out:
# Shape of train:  (1168, 81)
# Shape of test:  (292, 80)

# %%
train.head(10)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   127         120       RL          NaN     4928   Pave   NaN      IR1
# 1   889          20       RL         95.0    15865   Pave   NaN      IR1
# 2   793          60       RL         92.0     9920   Pave   NaN      IR1
# 3   110          20       RL        105.0    11751   Pave   NaN      IR1
# 4   422          20       RL          NaN    16635   Pave   NaN      IR1
# 5  1197          60       RL         58.0    14054   Pave   NaN      IR1
# 6   561          20       RL          NaN    11341   Pave   NaN      IR1
# 7  1041          20       RL         88.0    13125   Pave   NaN      Reg
# 8   503          20       RL         70.0     9170   Pave   NaN      Reg
# 9   576          50       RL         80.0     8480   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 4         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 5         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 6         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 7         Lvl    AllPub  ...        0    NaN  GdPrv         NaN       0
# 8         Lvl    AllPub  ...        0    NaN  GdPrv        Shed     400
# 9         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2007        WD         Normal     128000
# 1     10   2007        WD         Normal     268000
# 2      6   2007        WD         Normal     269790
# 3      1   2010       COD         Normal     190000
# 4      6   2009        WD         Normal     215000
# 5     11   2006       New        Partial     219210
# 6      5   2010        WD         Normal     121500
# 7      1   2006        WD         Normal     155000
# 8      4   2007        WD         Normal     140000
# 9     10   2008       COD        Abnorml     118500
#
# [10 rows x 81 columns]

# %%
test.head(10)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL         86.0    14157   Pave   NaN      IR1
# 1  1018         120       RL          NaN     5814   Pave   NaN      IR1
# 2   929          20       RL          NaN    11838   Pave   NaN      Reg
# 3  1148          70       RL         75.0    12000   Pave   NaN      Reg
# 4  1227          60       RL         86.0    14598   Pave   NaN      IR1
# 5   650         180       RM         21.0     1936   Pave   NaN      Reg
# 6  1453         180       RM         35.0     3675   Pave   NaN      Reg
# 7   152          20       RL        107.0    13891   Pave   NaN      Reg
# 8   427          80       RL          NaN    12800   Pave   NaN      Reg
# 9   776         120       RM         32.0     4500   Pave   NaN      Reg
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         HLS    AllPub  ...           0        0    NaN    NaN         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 2         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 3         Bnk    AllPub  ...           0        0    NaN    NaN         NaN
# 4         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 5         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 6         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 7         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 8         Low    AllPub  ...         396        0    NaN    NaN         NaN
# 9         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0       0      7    2007        WD         Normal
# 1       0      8    2009       COD        Abnorml
# 2       0      6    2009        WD         Normal
# 3       0      7    2009        WD         Normal
# 4       0      1    2008        WD         Normal
# 5       0     12    2007        WD         Normal
# 6       0      5    2006        WD         Normal
# 7       0      1    2008       New        Partial
# 8       0      8    2009        WD         Normal
# 9       0      6    2009        WD         Normal
#
# [10 rows x 80 columns]

# %%
## concat train and test
df = pd.concat((train, test))
temp_df = df
print("Shape of df: ", df.shape)
# Out:
# Shape of df:  (1460, 81)

# %%
df.head(6)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   127         120       RL          NaN     4928   Pave   NaN      IR1
# 1   889          20       RL         95.0    15865   Pave   NaN      IR1
# 2   793          60       RL         92.0     9920   Pave   NaN      IR1
# 3   110          20       RL        105.0    11751   Pave   NaN      IR1
# 4   422          20       RL          NaN    16635   Pave   NaN      IR1
# 5  1197          60       RL         58.0    14054   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 4         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 5         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2007        WD         Normal   128000.0
# 1     10   2007        WD         Normal   268000.0
# 2      6   2007        WD         Normal   269790.0
# 3      1   2010       COD         Normal   190000.0
# 4      6   2009        WD         Normal   215000.0
# 5     11   2006       New        Partial   219210.0
#
# [6 rows x 81 columns]

# %%
df.tail(6)
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 286    56          20       RL        100.0    10175   Pave   NaN      IR1
# 287    83          20       RL         78.0    10206   Pave   NaN      Reg
# 288  1048          20       RL         57.0     9245   Pave   NaN      IR2
# 289    17          20       RL          NaN    11241   Pave   NaN      IR1
# 290   523          50       RM         50.0     5000   Pave   NaN      Reg
# 291  1379         160       RM         21.0     1953   Pave   NaN      Reg
#
#     LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 286         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 287         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 288         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 289         Lvl    AllPub  ...        0    NaN   NaN        Shed     700
# 290         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 291         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 286      7   2008        WD         Normal        NaN
# 287     10   2008        WD         Normal        NaN
# 288      2   2008        WD         Normal        NaN
# 289      3   2010        WD         Normal        NaN
# 290     10   2006        WD         Normal        NaN
# 291      6   2006        WD         Normal        NaN
#
# [6 rows x 81 columns]

# %% [markdown]
# ## Exploratory Data Analysis (EDA)¶

# %%
# To show the all columns
pd.set_option("display.max_columns", 2000)
pd.set_option("display.max_rows", 85)

# %%
df.head(6)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   127         120       RL          NaN     4928   Pave   NaN      IR1
# 1   889          20       RL         95.0    15865   Pave   NaN      IR1
# 2   793          60       RL         92.0     9920   Pave   NaN      IR1
# 3   110          20       RL        105.0    11751   Pave   NaN      IR1
# 4   422          20       RL          NaN    16635   Pave   NaN      IR1
# 5  1197          60       RL         58.0    14054   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      NPkVill       Norm
# 1         Lvl    AllPub    Inside       Mod        NAmes       Norm
# 2         Lvl    AllPub   CulDSac       Gtl      NoRidge       Norm
# 3         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 4         Lvl    AllPub       FR2       Gtl       NWAmes       Norm
# 5         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm   TwnhsE     1Story            6            5       1976
# 1       Norm     1Fam     1Story            8            6       1970
# 2       Norm     1Fam     2Story            7            5       1996
# 3       Norm     1Fam     1Story            6            6       1977
# 4       Norm     1Fam     1Story            6            7       1977
# 5       Norm     1Fam     2Story            7            5       2006
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          1976     Gable  CompShg     Plywood     Plywood       None
# 1          1970      Flat  Tar&Grv     Wd Sdng     Wd Sdng       None
# 2          1997     Gable  CompShg     MetalSd     MetalSd       None
# 3          1977       Hip  CompShg     Plywood     Plywood    BrkFace
# 4          2000     Gable  CompShg     CemntBd     CmentBd      Stone
# 5          2006     Gable  CompShg     VinylSd     VinylSd       None
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0         0.0        TA        TA     CBlock       Gd       TA           No
# 1         0.0        Gd        Gd      PConc       TA       Gd           Gd
# 2         0.0        Gd        TA      PConc       Gd       TA           Av
# 3       480.0        TA        TA     CBlock       Gd       TA           No
# 4       126.0        Gd        TA     CBlock       Gd       TA           No
# 5         0.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          ALQ         120          Unf           0        958         1078
# 1          ALQ         351          Rec         823       1043         2217
# 2          GLQ         862          Unf           0        255         1117
# 3          BLQ         705          Unf           0       1139         1844
# 4          ALQ        1246          Unf           0        356         1602
# 5          Unf           0          Unf           0        879          879
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        TA          Y      SBrkr       958         0             0
# 1    GasA        Ex          Y      SBrkr      2217         0             0
# 2    GasA        Ex          Y      SBrkr      1127       886             0
# 3    GasA        Ex          Y      SBrkr      1844         0             0
# 4    GasA        Gd          Y      SBrkr      1602         0             0
# 5    GasA        Ex          Y      SBrkr       879       984             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0        958             0             0         2         0             2
# 1       2217             1             0         2         0             4
# 2       2013             1             0         2         1             3
# 3       1844             0             0         2         0             3
# 4       1602             0             1         2         0             3
# 5       1863             0             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          TA             5        Typ           1          TA
# 1             1          Gd             8        Typ           1          TA
# 2             1          TA             8        Typ           1          TA
# 3             1          TA             7        Typ           1          TA
# 4             1          Gd             8        Typ           1          TA
# 5             1          Gd             9        Typ           1          Gd
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       1977.0          RFn           2         440         TA
# 1     Attchd       1970.0          Unf           2         621         TA
# 2     Attchd       1997.0          Unf           2         455         TA
# 3     Attchd       1977.0          RFn           2         546         TA
# 4     Attchd       1977.0          Fin           2         529         TA
# 5    BuiltIn       2006.0          Fin           3         660         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0          205              0          0
# 1         TA          Y          81          207              0          0
# 2         TA          Y         180          130              0          0
# 3         TA          Y           0          122              0          0
# 4         TA          Y         240            0              0          0
# 5         TA          Y         100           17              0          0
#
#    ScreenPorch  PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN    NaN         NaN        0       2    2007
# 1          224         0    NaN    NaN         NaN        0      10    2007
# 2            0         0    NaN    NaN         NaN        0       6    2007
# 3            0         0    NaN  MnPrv         NaN        0       1    2010
# 4            0         0    NaN    NaN         NaN        0       6    2009
# 5            0         0    NaN    NaN         NaN        0      11    2006
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal   128000.0
# 1       WD        Normal   268000.0
# 2       WD        Normal   269790.0
# 3      COD        Normal   190000.0
# 4       WD        Normal   215000.0
# 5      New       Partial   219210.0

# %%
df.tail(6)
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 286    56          20       RL        100.0    10175   Pave   NaN      IR1
# 287    83          20       RL         78.0    10206   Pave   NaN      Reg
# 288  1048          20       RL         57.0     9245   Pave   NaN      IR2
# 289    17          20       RL          NaN    11241   Pave   NaN      IR1
# 290   523          50       RM         50.0     5000   Pave   NaN      Reg
# 291  1379         160       RM         21.0     1953   Pave   NaN      Reg
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 286         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 287         Lvl    AllPub    Inside       Gtl      Somerst       Norm
# 288         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 289         Lvl    AllPub   CulDSac       Gtl        NAmes       Norm
# 290         Lvl    AllPub    Corner       Gtl      BrkSide      Feedr
# 291         Lvl    AllPub    Inside       Gtl       BrDale       Norm
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 286       Norm     1Fam     1Story            6            5       1964
# 287       Norm     1Fam     1Story            8            5       2007
# 288       Norm     1Fam     1Story            5            5       1994
# 289       Norm     1Fam     1Story            6            7       1970
# 290       Norm     1Fam     1.5Fin            6            7       1947
# 291       Norm    Twnhs     2Story            6            5       1973
#
#      YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 286          1964     Gable  CompShg     HdBoard     Plywood    BrkFace
# 287          2007     Gable  CompShg     VinylSd     VinylSd      Stone
# 288          1995     Gable  CompShg     VinylSd     VinylSd       None
# 289          1970     Gable  CompShg     Wd Sdng     Wd Sdng    BrkFace
# 290          1950     Gable  CompShg     CemntBd     CmentBd       None
# 291          1973     Gable  CompShg     HdBoard     HdBoard    BrkFace
#
#      MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 286       272.0        TA        TA     CBlock       TA       TA           No
# 287       468.0        TA        TA      PConc       Gd       TA           No
# 288         0.0        TA        TA      PConc       Gd       TA           No
# 289       180.0        TA        TA     CBlock       TA       TA           No
# 290         0.0        TA        Gd     CBlock       TA       TA           No
# 291       408.0        TA        TA     CBlock       TA       Fa           No
#
#     BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 286          BLQ         490          Unf           0        935         1425
# 287          GLQ          33          Unf           0       1530         1563
# 288          GLQ         686          Unf           0        304          990
# 289          ALQ         578          Unf           0        426         1004
# 290          ALQ         399          Unf           0        605         1004
# 291          BLQ         309          Unf           0        174          483
#
#     Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 286    GasA        Gd          Y      SBrkr      1425         0             0
# 287    GasA        Ex          Y      SBrkr      1563         0             0
# 288    GasA        Ex          Y      SBrkr       990         0             0
# 289    GasA        Ex          Y      SBrkr      1004         0             0
# 290    GasA        Ex          Y      SBrkr      1004       660             0
# 291    GasA        TA          Y      SBrkr       483       504             0
#
#      GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 286       1425             0             0         2         0             3
# 287       1563             0             0         2         0             3
# 288        990             0             1         1         0             3
# 289       1004             1             0         1         0             2
# 290       1664             0             0         2         0             3
# 291        987             0             0         1         1             2
#
#      KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces  \
# 286             1          TA             7        Typ           1
# 287             1          Gd             6        Typ           1
# 288             1          TA             5        Typ           0
# 289             1          TA             5        Typ           1
# 290             1          TA             7        Typ           2
# 291             1          TA             5        Typ           0
#
#     FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea  \
# 286          Gd     Attchd       1964.0          RFn           2         576
# 287          Gd     Attchd       2007.0          RFn           3         758
# 288         NaN     Detchd       1996.0          Unf           2         672
# 289          TA     Attchd       1970.0          Fin           2         480
# 290          Gd     Detchd       1950.0          Unf           2         420
# 291         NaN     Detchd       1973.0          Unf           1         264
#
#     GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# 286         TA         TA          Y           0            0              0
# 287         TA         TA          Y         144           99              0
# 288         TA         TA          Y           0            0              0
# 289         TA         TA          Y           0            0              0
# 290         TA         TA          Y           0           24             36
# 291         TA         TA          Y          72            0              0
#
#      3SsnPorch  ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  \
# 286        407            0         0    NaN   NaN         NaN        0
# 287          0            0         0    NaN   NaN         NaN        0
# 288          0            0         0    NaN   NaN         NaN        0
# 289          0            0         0    NaN   NaN        Shed      700
# 290          0            0         0    NaN   NaN         NaN        0
# 291          0            0         0    NaN   NaN         NaN        0
#
#      MoSold  YrSold SaleType SaleCondition  SalePrice
# 286       7    2008       WD        Normal        NaN
# 287      10    2008       WD        Normal        NaN
# 288       2    2008       WD        Normal        NaN
# 289       3    2010       WD        Normal        NaN
# 290      10    2006       WD        Normal        NaN
# 291       6    2006       WD        Normal        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 0 to 291
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     1452 non-null   object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1168 non-null   float64
# dtypes: float64(4), int64(34), object(43)
# memory usage: 935.3+ KB

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000
#
#         BsmtFinSF2    BsmtUnfSF  TotalBsmtSF     1stFlrSF     2ndFlrSF  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean     46.549315   567.240411  1057.429452  1162.626712   346.992466
# std     161.319273   441.866955   438.705324   386.587738   436.528436
# min       0.000000     0.000000     0.000000   334.000000     0.000000
# 25%       0.000000   223.000000   795.750000   882.000000     0.000000
# 50%       0.000000   477.500000   991.500000  1087.000000     0.000000
# 75%       0.000000   808.000000  1298.250000  1391.250000   728.000000
# max    1474.000000  2336.000000  6110.000000  4692.000000  2065.000000
#
#        LowQualFinSF    GrLivArea  BsmtFullBath  BsmtHalfBath     FullBath  \
# count   1460.000000  1460.000000   1460.000000   1460.000000  1460.000000
# mean       5.844521  1515.463699      0.425342      0.057534     1.565068
# std       48.623081   525.480383      0.518911      0.238753     0.550916
# min        0.000000   334.000000      0.000000      0.000000     0.000000
# 25%        0.000000  1129.500000      0.000000      0.000000     1.000000
# 50%        0.000000  1464.000000      0.000000      0.000000     2.000000
# 75%        0.000000  1776.750000      1.000000      0.000000     2.000000
# max      572.000000  5642.000000      3.000000      2.000000     3.000000
#
#           HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd   Fireplaces  \
# count  1460.000000   1460.000000   1460.000000   1460.000000  1460.000000
# mean      0.382877      2.866438      1.046575      6.517808     0.613014
# std       0.502885      0.815778      0.220338      1.625393     0.644666
# min       0.000000      0.000000      0.000000      2.000000     0.000000
# 25%       0.000000      2.000000      1.000000      5.000000     0.000000
# 50%       0.000000      3.000000      1.000000      6.000000     1.000000
# 75%       1.000000      3.000000      1.000000      7.000000     1.000000
# max       2.000000      8.000000      3.000000     14.000000     3.000000
#
#        GarageYrBlt   GarageCars   GarageArea   WoodDeckSF  OpenPorchSF  \
# count  1379.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean   1978.506164     1.767123   472.980137    94.244521    46.660274
# std      24.689725     0.747315   213.804841   125.338794    66.256028
# min    1900.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1961.000000     1.000000   334.500000     0.000000     0.000000
# 50%    1980.000000     2.000000   480.000000     0.000000    25.000000
# 75%    2002.000000     2.000000   576.000000   168.000000    68.000000
# max    2010.000000     4.000000  1418.000000   857.000000   547.000000
#
#        EnclosedPorch    3SsnPorch  ScreenPorch     PoolArea       MiscVal  \
# count    1460.000000  1460.000000  1460.000000  1460.000000   1460.000000
# mean       21.954110     3.409589    15.060959     2.758904     43.489041
# std        61.119149    29.317331    55.757415    40.177307    496.123024
# min         0.000000     0.000000     0.000000     0.000000      0.000000
# 25%         0.000000     0.000000     0.000000     0.000000      0.000000
# 50%         0.000000     0.000000     0.000000     0.000000      0.000000
# 75%         0.000000     0.000000     0.000000     0.000000      0.000000
# max       552.000000   508.000000   480.000000   738.000000  15500.000000
#
#             MoSold       YrSold      SalePrice
# count  1460.000000  1460.000000    1168.000000
# mean      6.321918  2007.815753  181477.005993
# std       2.703626     1.328095   79105.586863
# min       1.000000  2006.000000   34900.000000
# 25%       5.000000  2007.000000  130375.000000
# 50%       6.000000  2008.000000  163995.000000
# 75%       8.000000  2009.000000  215000.000000
# max      12.000000  2010.000000  755000.000000

# %%
df.select_dtypes(include=['int64', 'float64']).columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
df.select_dtypes(include=['object']).columns
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
# Set index as Id column
df = df.set_index("Id")

# %%
df.head(6)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 127          120       RL          NaN     4928   Pave   NaN      IR1
# 889           20       RL         95.0    15865   Pave   NaN      IR1
# 793           60       RL         92.0     9920   Pave   NaN      IR1
# 110           20       RL        105.0    11751   Pave   NaN      IR1
# 422           20       RL          NaN    16635   Pave   NaN      IR1
# 1197          60       RL         58.0    14054   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 127          Lvl    AllPub    Inside       Gtl      NPkVill       Norm
# 889          Lvl    AllPub    Inside       Mod        NAmes       Norm
# 793          Lvl    AllPub   CulDSac       Gtl      NoRidge       Norm
# 110          Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 422          Lvl    AllPub       FR2       Gtl       NWAmes       Norm
# 1197         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 127        Norm   TwnhsE     1Story            6            5       1976
# 889        Norm     1Fam     1Story            8            6       1970
# 793        Norm     1Fam     2Story            7            5       1996
# 110        Norm     1Fam     1Story            6            6       1977
# 422        Norm     1Fam     1Story            6            7       1977
# 1197       Norm     1Fam     2Story            7            5       2006
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 127           1976     Gable  CompShg     Plywood     Plywood       None
# 889           1970      Flat  Tar&Grv     Wd Sdng     Wd Sdng       None
# 793           1997     Gable  CompShg     MetalSd     MetalSd       None
# 110           1977       Hip  CompShg     Plywood     Plywood    BrkFace
# 422           2000     Gable  CompShg     CemntBd     CmentBd      Stone
# 1197          2006     Gable  CompShg     VinylSd     VinylSd       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# Id
# 127          0.0        TA        TA     CBlock       Gd       TA
# 889          0.0        Gd        Gd      PConc       TA       Gd
# 793          0.0        Gd        TA      PConc       Gd       TA
# 110        480.0        TA        TA     CBlock       Gd       TA
# 422        126.0        Gd        TA     CBlock       Gd       TA
# 1197         0.0        Gd        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# Id
# 127            No          ALQ         120          Unf           0
# 889            Gd          ALQ         351          Rec         823
# 793            Av          GLQ         862          Unf           0
# 110            No          BLQ         705          Unf           0
# 422            No          ALQ        1246          Unf           0
# 1197           Av          Unf           0          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# Id
# 127         958         1078    GasA        TA          Y      SBrkr
# 889        1043         2217    GasA        Ex          Y      SBrkr
# 793         255         1117    GasA        Ex          Y      SBrkr
# 110        1139         1844    GasA        Ex          Y      SBrkr
# 422         356         1602    GasA        Gd          Y      SBrkr
# 1197        879          879    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 127        958         0             0        958             0             0
# 889       2217         0             0       2217             1             0
# 793       1127       886             0       2013             1             0
# 110       1844         0             0       1844             0             0
# 422       1602         0             0       1602             0             1
# 1197       879       984             0       1863             0             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# Id
# 127          2         0             2             1          TA
# 889          2         0             4             1          Gd
# 793          2         1             3             1          TA
# 110          2         0             3             1          TA
# 422          2         0             3             1          Gd
# 1197         2         1             4             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# Id
# 127              5        Typ           1          TA     Attchd       1977.0
# 889              8        Typ           1          TA     Attchd       1970.0
# 793              8        Typ           1          TA     Attchd       1997.0
# 110              7        Typ           1          TA     Attchd       1977.0
# 422              8        Typ           1          TA     Attchd       1977.0
# 1197             9        Typ           1          Gd    BuiltIn       2006.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# Id
# 127           RFn           2         440         TA         TA          Y
# 889           Unf           2         621         TA         TA          Y
# 793           Unf           2         455         TA         TA          Y
# 110           RFn           2         546         TA         TA          Y
# 422           Fin           2         529         TA         TA          Y
# 1197          Fin           3         660         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# Id
# 127            0          205              0          0            0
# 889           81          207              0          0          224
# 793          180          130              0          0            0
# 110            0          122              0          0            0
# 422          240            0              0          0            0
# 1197         100           17              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# Id
# 127          0    NaN    NaN         NaN        0       2    2007       WD
# 889          0    NaN    NaN         NaN        0      10    2007       WD
# 793          0    NaN    NaN         NaN        0       6    2007       WD
# 110          0    NaN  MnPrv         NaN        0       1    2010      COD
# 422          0    NaN    NaN         NaN        0       6    2009       WD
# 1197         0    NaN    NaN         NaN        0      11    2006      New
#
#      SaleCondition  SalePrice
# Id
# 127         Normal   128000.0
# 889         Normal   268000.0
# 793         Normal   269790.0
# 110         Normal   190000.0
# 422         Normal   215000.0
# 1197       Partial   219210.0

# %%
# Show the null values using heatmap
plt.figure(figsize=(16,9))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:ylabel='Id'>

# %%
# Get the percentages of null value
null_percent = df.isnull().sum()/df.shape[0]*100
null_percent
# Out:
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.739726
# LotArea           0.000000
# Street            0.000000
# Alley            93.767123
# LotShape          0.000000
# LandContour       0.000000
# Utilities         0.000000
# LotConfig         0.000000
# LandSlope         0.000000
# Neighborhood      0.000000
# Condition1        0.000000
# Condition2        0.000000
# BldgType          0.000000
# HouseStyle        0.000000
# OverallQual       0.000000
# OverallCond       0.000000
# YearBuilt         0.000000
# YearRemodAdd      0.000000
# RoofStyle         0.000000
# RoofMatl          0.000000
# Exterior1st       0.000000
# Exterior2nd       0.000000
# MasVnrType        0.547945
# MasVnrArea        0.547945
# ExterQual         0.000000
# ExterCond         0.000000
# Foundation        0.000000
# BsmtQual          2.534247
# BsmtCond          2.534247
# BsmtExposure      2.602740
# BsmtFinType1      2.534247
# BsmtFinSF1        0.000000
# BsmtFinType2      2.602740
# BsmtFinSF2        0.000000
# BsmtUnfSF         0.000000
# TotalBsmtSF       0.000000
# Heating           0.000000
# HeatingQC         0.000000
# CentralAir        0.000000
# Electrical        0.068493
# 1stFlrSF          0.000000
# 2ndFlrSF          0.000000
# LowQualFinSF      0.000000
# GrLivArea         0.000000
# BsmtFullBath      0.000000
# BsmtHalfBath      0.000000
# FullBath          0.000000
# HalfBath          0.000000
# BedroomAbvGr      0.000000
# KitchenAbvGr      0.000000
# KitchenQual       0.000000
# TotRmsAbvGrd      0.000000
# Functional        0.000000
# Fireplaces        0.000000
# FireplaceQu      47.260274
# GarageType        5.547945
# GarageYrBlt       5.547945
# GarageFinish      5.547945
# GarageCars        0.000000
# GarageArea        0.000000
# GarageQual        5.547945
# GarageCond        5.547945
# PavedDrive        0.000000
# WoodDeckSF        0.000000
# OpenPorchSF       0.000000
# EnclosedPorch     0.000000
# 3SsnPorch         0.000000
# ScreenPorch       0.000000
# PoolArea          0.000000
# PoolQC           99.520548
# Fence            80.753425
# MiscFeature      96.301370
# MiscVal           0.000000
# MoSold            0.000000
# YrSold            0.000000
# SaleType          0.000000
# SaleCondition     0.000000
# SalePrice        20.000000
# dtype: float64

# %%
col_for_drop = null_percent[null_percent > 20].keys() # if the null value % 20 or > 20 so need to drop it

# %%
# drop columns
df = df.drop(col_for_drop, "columns")
df.shape
# Out:
# C:\Users\Visual singh\AppData\Local\Temp\ipykernel_16044\3521000289.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop(col_for_drop, "columns")
# (1460, 75)

# %%
# find the unique value count
for i in df.columns:
    print(i + "\t" + str(len(df[i].unique())))
# Out:
# MSSubClass	15
# MSZoning	5
# LotFrontage	111
# LotArea	1073
# Street	2
# LotShape	4
# LandContour	4
# Utilities	2
# LotConfig	5
# LandSlope	3
# Neighborhood	25
# Condition1	9
# Condition2	8
# BldgType	5
# HouseStyle	8
# OverallQual	10
# OverallCond	9
# YearBuilt	112
# YearRemodAdd	61
# RoofStyle	6
# RoofMatl	8
# Exterior1st	15
# Exterior2nd	16
# MasVnrType	5
# MasVnrArea	328
# ExterQual	4
# ExterCond	5
# Foundation	6
# BsmtQual	5
# BsmtCond	5
# BsmtExposure	5
# BsmtFinType1	7
# BsmtFinSF1	637
# BsmtFinType2	7
# BsmtFinSF2	144
# BsmtUnfSF	780
# TotalBsmtSF	721
# Heating	6
# HeatingQC	5
# CentralAir	2
# Electrical	6
# 1stFlrSF	753
# 2ndFlrSF	417
# LowQualFinSF	24
# GrLivArea	861
# BsmtFullBath	4
# BsmtHalfBath	3
# FullBath	4
# HalfBath	3
# BedroomAbvGr	8
# KitchenAbvGr	4
# KitchenQual	4
# TotRmsAbvGrd	12
# Functional	7
# Fireplaces	4
# GarageType	7
# GarageYrBlt	98
# GarageFinish	4
# GarageCars	5
# GarageArea	441
# GarageQual	6
# GarageCond	6
# PavedDrive	3
# WoodDeckSF	274
# OpenPorchSF	202
# EnclosedPorch	120
# 3SsnPorch	20
# ScreenPorch	76
# PoolArea	8
# MiscVal	21
# MoSold	12
# YrSold	5
# SaleType	9
# SaleCondition	6
# SalePrice	582

# %%
# find unique values of each column
for i in df.columns:
    print("Unique value of:>>> {} ({})\n{}\n".format(i, len(df[i].unique()), df[i].unique()))
# Out:
# Unique value of:>>> MSSubClass (15)
# [120  20  60  50  70  30 160  85  45  90  40  80 190  75 180]
#
# Unique value of:>>> MSZoning (5)
# ['RL' 'RM' 'FV' 'RH' 'C (all)']
#
# Unique value of:>>> LotFrontage (111)
# [ nan  95.  92. 105.  58.  88.  70.  80.  50.  44. 129.  59.  55.  64.
#   24.  68.  71.  74.  61.  60. 120.  84. 141.  30.  65.  76. 100.  85.
#   75. 107. 122.  82.  62.  73.  79.  77.  41.  69.  90.  96.  72.  34.
#   78.  63.  40.  98. 160. 108. 128.  51.  81.  99.  66.  37. 174.  87.
#   53. 152.  47.  86.  56.  89.  35.  52.  21. 104.  57.  83.  46. 101.
#  112. 149.  93.  49.  43. 130.  54.  91.  67.  97. 110. 103. 115.  94.
#   48.  36. 313. 109. 144. 121. 102. 116. 182.  32.  42. 168. 118.  38.
#  140. 134. 114. 124.  39. 111.  45. 106. 153.  33. 138. 137. 150.]
#
# Unique value of:>>> LotArea (1073)
# [ 4928 15865  9920 ... 10175 11241  1953]
#
# Unique value of:>>> Street (2)
# ['Pave' 'Grvl']
#
# Unique value of:>>> LotShape (4)
# ['IR1' 'Reg' 'IR2' 'IR3']
#
# Unique value of:>>> LandContour (4)
# ['Lvl' 'Bnk' 'HLS' 'Low']
#
# Unique value of:>>> Utilities (2)
# ['AllPub' 'NoSeWa']
#
# Unique value of:>>> LotConfig (5)
# ['Inside' 'CulDSac' 'FR2' 'Corner' 'FR3']
#
# Unique value of:>>> LandSlope (3)
# ['Gtl' 'Mod' 'Sev']
#
# Unique value of:>>> Neighborhood (25)
# ['NPkVill' 'NAmes' 'NoRidge' 'NWAmes' 'Gilbert' 'Sawyer' 'Edwards'
#  'IDOTRR' 'CollgCr' 'Mitchel' 'Crawfor' 'BrDale' 'StoneBr' 'BrkSide'
#  'NridgHt' 'OldTown' 'Somerst' 'Timber' 'SWISU' 'SawyerW' 'ClearCr'
#  'Veenker' 'Blmngtn' 'MeadowV' 'Blueste']
#
# Unique value of:>>> Condition1 (9)
# ['Norm' 'Feedr' 'RRAn' 'PosA' 'RRAe' 'Artery' 'PosN' 'RRNe' 'RRNn']
#
# Unique value of:>>> Condition2 (8)
# ['Norm' 'RRAe' 'Feedr' 'PosN' 'Artery' 'RRNn' 'PosA' 'RRAn']
#
# Unique value of:>>> BldgType (5)
# ['TwnhsE' '1Fam' 'Duplex' 'Twnhs' '2fmCon']
#
# Unique value of:>>> HouseStyle (8)
# ['1Story' '2Story' '1.5Fin' 'SFoyer' '1.5Unf' 'SLvl' '2.5Fin' '2.5Unf']
#
# Unique value of:>>> OverallQual (10)
# [ 6  8  7  5  9  1  2  4  3 10]
#
# Unique value of:>>> OverallCond (9)
# [5 6 7 4 8 2 3 9 1]
#
# Unique value of:>>> YearBuilt (112)
# [1976 1970 1996 1977 2006 1957 1965 1947 1937 2003 1960 1955 1923 1930
#  2007 2001 1972 1950 1961 1953 1918 2010 1922 1934 2005 1946 1941 1948
#  1975 1978 1956 2004 1982 2000 2002 1920 1992 1936 1967 1989 1929 1968
#  1959 1935 1966 1931 1916 1998 1962 1974 1926 1904 1995 1969 1985 1963
#  1958 1892 2008 1971 1980 1945 1986 1981 1949 1940 1954 1925 1915 1921
#  1924 1999 1951 1993 1964 1900 1919 1910 1938 1880 1988 1911 1990 1979
#  1927 1983 1994 2009 1928 1917 1898 1997 1984 1973 1952 1939 1987 1890
#  1942 1991 1932 1908 1914 1882 1905 1875 1906 1893 1912 1913 1885 1872]
#
# Unique value of:>>> YearRemodAdd (61)
# [1976 1970 1997 1977 2000 2006 1996 1965 1950 2003 1960 1955 2007 2001
#  1961 1998 1953 2010 1995 2005 1992 1975 1978 1982 2002 1989 1967 1968
#  1959 2004 1966 2008 1987 1981 1969 1985 1963 1991 1993 1971 1990 1956
#  1986 1999 1954 1957 1994 1972 1958 1980 1979 1951 1983 2009 1962 1964
#  1952 1984 1988 1974 1973]
#
# Unique value of:>>> RoofStyle (6)
# ['Gable' 'Flat' 'Hip' 'Shed' 'Gambrel' 'Mansard']
#
# Unique value of:>>> RoofMatl (8)
# ['CompShg' 'Tar&Grv' 'WdShngl' 'WdShake' 'Roll' 'ClyTile' 'Metal'
#  'Membran']
#
# Unique value of:>>> Exterior1st (15)
# ['Plywood' 'Wd Sdng' 'MetalSd' 'CemntBd' 'VinylSd' 'HdBoard' 'Stucco'
#  'WdShing' 'BrkFace' 'Stone' 'AsbShng' 'AsphShn' 'ImStucc' 'BrkComm'
#  'CBlock']
#
# Unique value of:>>> Exterior2nd (16)
# ['Plywood' 'Wd Sdng' 'MetalSd' 'CmentBd' 'VinylSd' 'HdBoard' 'Wd Shng'
.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
# Plot the distplot of target
plt.figure(figsize=(10,8))
bar = sns.distplot(train["SalePrice"])
bar.legend(["Skewness: {:.2f}".format(train['SalePrice'].skew())])
# Out:
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# correlation heatmap
plt.figure(figsize=(25,25))
ax = sns.heatmap(train.corr(), cmap = "coolwarm", annot=True, linewidth=2)

# to fix the bug "first and last row cut in half of heatmap plot"
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (38.5, -0.5)

# %%
# correlation heatmap of higly correlated features with SalePrice
hig_corr = train.corr()
hig_corr_features = hig_corr.index[abs(hig_corr["SalePrice"]) >= 0.5]
hig_corr_features
# Out:
# Index(['OverallQual', 'YearBuilt', 'YearRemodAdd', 'TotalBsmtSF', '1stFlrSF',
#        'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'GarageCars', 'GarageArea',
#        'SalePrice'],
#       dtype='object')

# %%
plt.figure(figsize=(10,8))
ax = sns.heatmap(train[hig_corr_features].corr(), cmap = "coolwarm", annot=True, linewidth=3)
# to fix the bug "first and last row cut in half of heatmap plot"
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (11.5, -0.5)

# %%
# Plot regplot to get the nature of highly correlated data
plt.figure(figsize=(16,9))
for i in range(len(hig_corr_features)):
    if i <= 9:
        plt.subplot(3,4,i+1)
        plt.subplots_adjust(hspace = 0.5, wspace = 0.5)
        sns.regplot(data=train, x = hig_corr_features[i], y = 'SalePrice')

# %% [markdown]
# ## Handling Missing Value

# %%
missing_col = df.columns[df.isnull().any()]
missing_col
# Out:
# Index(['LotFrontage', 'MasVnrType', 'MasVnrArea', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Electrical',
#        'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageQual', 'GarageCond',
#        'SalePrice'],
#       dtype='object')

# %% [markdown]
# ## Handling missing value of Bsmt feature

# %%
bsmt_col = ['BsmtCond', 'BsmtExposure', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtFinType1',
       'BsmtFinType2', 'BsmtFullBath', 'BsmtHalfBath', 'BsmtQual', 'BsmtUnfSF', 'TotalBsmtSF']
bsmt_feat = df[bsmt_col]
bsmt_feat
# Out:
#      BsmtCond BsmtExposure  BsmtFinSF1  BsmtFinSF2 BsmtFinType1 BsmtFinType2  \
# Id
# 127        TA           No         120           0          ALQ          Unf
# 889        Gd           Gd         351         823          ALQ          Rec
# 793        TA           Av         862           0          GLQ          Unf
# 110        TA           No         705           0          BLQ          Unf
# 422        TA           No        1246           0          ALQ          Unf
# ...       ...          ...         ...         ...          ...          ...
# 83         TA           No          33           0          GLQ          Unf
# 1048       TA           No         686           0          GLQ          Unf
# 17         TA           No         578           0          ALQ          Unf
# 523        TA           No         399           0          ALQ          Unf
# 1379       Fa           No         309           0          BLQ          Unf
#
#       BsmtFullBath  BsmtHalfBath BsmtQual  BsmtUnfSF  TotalBsmtSF
# Id
# 127              0             0       Gd        958         1078
# 889              1             0       TA       1043         2217
# 793              1             0       Gd        255         1117
# 110              0             0       Gd       1139         1844
# 422              0             1       Gd        356         1602
# ...            ...           ...      ...        ...          ...
# 83               0             0       Gd       1530         1563
# 1048             0             1       Gd        304          990
# 17               1             0       TA        426         1004
# 523              0             0       TA        605         1004
# 1379             0             0       TA        174          483
#
# [1460 rows x 11 columns]

# %%
bsmt_feat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 127 to 1379
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   BsmtCond      1423 non-null   object
#  1   BsmtExposure  1422 non-null   object
#  2   BsmtFinSF1    1460 non-null   int64
#  3   BsmtFinSF2    1460 non-null   int64
#  4   BsmtFinType1  1423 non-null   object
#  5   BsmtFinType2  1422 non-null   object
#  6   BsmtFullBath  1460 non-null   int64
#  7   BsmtHalfBath  1460 non-null   int64
#  8   BsmtQual      1423 non-null   object
#  9   BsmtUnfSF     1460 non-null   int64
#  10  TotalBsmtSF   1460 non-null   int64
# dtypes: int64(6), object(5)
# memory usage: 136.9+ KB

# %%
bsmt_feat.isnull().sum()
# Out:
# BsmtCond        37
# BsmtExposure    38
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtFinType1    37
# BsmtFinType2    38
# BsmtFullBath     0
# BsmtHalfBath     0
# BsmtQual        37
# BsmtUnfSF        0
# TotalBsmtSF      0
# dtype: int64

# %%
bsmt_feat = bsmt_feat[bsmt_feat.isnull().any(axis=1)]
bsmt_feat
# Out:
#      BsmtCond BsmtExposure  BsmtFinSF1  BsmtFinSF2 BsmtFinType1 BsmtFinType2  \
# Id
# 869       NaN          NaN           0           0          NaN          NaN
# 534       NaN          NaN           0           0          NaN          NaN
# 1050      NaN          NaN           0           0          NaN          NaN
# 533       NaN          NaN           0           0          NaN          NaN
# 157       NaN          NaN           0           0          NaN          NaN
# 779       NaN          NaN           0           0          NaN          NaN
# 91        NaN          NaN           0           0          NaN          NaN
# 393       NaN          NaN           0           0          NaN          NaN
# 1322      NaN          NaN           0           0          NaN          NaN
# 183       NaN          NaN           0           0          NaN          NaN
# 333        TA           No        1124         479          GLQ          NaN
# 1049      NaN          NaN           0           0          NaN          NaN
# 949        TA          NaN           0           0          Unf          Unf
# 750       NaN          NaN           0           0          NaN          NaN
# 363       NaN          NaN           0           0          NaN          NaN
# 1012      NaN          NaN           0           0          NaN          NaN
# 898       NaN          NaN           0           0          NaN          NaN
# 1233      NaN          NaN           0           0          NaN          NaN
# 343       NaN          NaN           0           0          NaN          NaN
# 521       NaN          NaN           0           0          NaN          NaN
# 1091      NaN          NaN           0           0          NaN          NaN
# 18        NaN          NaN           0           0          NaN          NaN
# 1413      NaN          NaN           0           0          NaN          NaN
# 40        NaN          NaN           0           0          NaN          NaN
# 1046      NaN          NaN           0           0          NaN          NaN
# 895       NaN          NaN           0           0          NaN          NaN
# 1036      NaN          NaN           0           0          NaN          NaN
# 1180      NaN          NaN           0           0          NaN          NaN
# 1219      NaN          NaN           0           0          NaN          NaN
# 103       NaN          NaN           0           0          NaN          NaN
# 985       NaN          NaN           0           0          NaN          NaN
# 554       NaN          NaN           0           0          NaN          NaN
# 706       NaN          NaN           0           0          NaN          NaN
# 1217      NaN          NaN           0           0          NaN          NaN
# 647       NaN          NaN           0           0          NaN          NaN
# 1001      NaN          NaN           0           0          NaN          NaN
# 737       NaN          NaN           0           0          NaN          NaN
# 260       NaN          NaN           0           0          NaN          NaN
# 372       NaN          NaN           0           0          NaN          NaN
#
#       BsmtFullBath  BsmtHalfBath BsmtQual  BsmtUnfSF  TotalBsmtSF
# Id
# 869              0             0      NaN          0            0
# 534              0             0      NaN          0            0
# 1050             0             0      NaN          0            0
# 533              0             0      NaN          0            0
# 157              0             0      NaN          0            0
# 779              0             0      NaN          0            0
# 91               0             0      NaN          0            0
# 393              0             0      NaN          0            0
# 1322             0             0      NaN          0            0
# 183              0             0      NaN          0            0
# 333              1             0       Gd       1603         3206
# 1049             0             0      NaN          0            0
# 949              0             0       Gd        936          936
# 750              0             0      NaN          0            0
# 363              0             0      NaN          0            0
# 1012             0             0      NaN          0            0
# 898              0             0      NaN          0            0
# 1233             0             0      NaN          0            0
# 343              0             0      NaN          0            0
# 521              0             0      NaN          0            0
# 1091             0             0      NaN          0            0
# 18               0             0      NaN          0            0
# 1413             0             0      NaN          0            0
# 40               0             0      NaN          0            0
# 1046             0             0      NaN          0            0
# 895              0             0      NaN          0            0
# 1036             0             0      NaN          0            0
# 1180             0             0      NaN          0            0
# 1219             0             0      NaN          0            0
# 103              0             0      NaN          0            0
# 985              0             0      NaN          0            0
# 554              0             0      NaN          0            0
# 706              0             0      NaN          0            0
# 1217             0             0      NaN          0            0
# 647              0             0      NaN          0            0
# 1001             0             0      NaN          0            0
# 737              0             0      NaN          0            0
# 260              0             0      NaN          0            0
# 372              0             0      NaN          0            0

# %%
bsmt_feat_all_nan = bsmt_feat[(bsmt_feat.isnull() | bsmt_feat.isin([0])).all(1)]
bsmt_feat_all_nan
# Out:
#      BsmtCond BsmtExposure  BsmtFinSF1  BsmtFinSF2 BsmtFinType1 BsmtFinType2  \
# Id
# 869       NaN          NaN           0           0          NaN          NaN
# 534       NaN          NaN           0           0          NaN          NaN
# 1050      NaN          NaN           0           0          NaN          NaN
# 533       NaN          NaN           0           0          NaN          NaN
# 157       NaN          NaN           0           0          NaN          NaN
# 779       NaN          NaN           0           0          NaN          NaN
# 91        NaN          NaN           0           0          NaN          NaN
# 393       NaN          NaN           0           0          NaN          NaN
# 1322      NaN          NaN           0           0          NaN          NaN
# 183       NaN          NaN           0           0          NaN          NaN
# 1049      NaN          NaN           0           0          NaN          NaN
# 750       NaN          NaN           0           0          NaN          NaN
# 363       NaN          NaN           0           0          NaN          NaN
# 1012      NaN          NaN           0           0          NaN          NaN
# 898       NaN          NaN           0           0          NaN          NaN
# 1233      NaN          NaN           0           0          NaN          NaN
# 343       NaN          NaN           0           0          NaN          NaN
# 521       NaN          NaN           0           0          NaN          NaN
# 1091      NaN          NaN           0           0          NaN          NaN
# 18        NaN          NaN           0           0          NaN          NaN
# 1413      NaN          NaN           0           0          NaN          NaN
# 40        NaN          NaN           0           0          NaN          NaN
# 1046      NaN          NaN           0           0          NaN          NaN
# 895       NaN          NaN           0           0          NaN          NaN
# 1036      NaN          NaN           0           0          NaN          NaN
# 1180      NaN          NaN           0           0          NaN          NaN
# 1219      NaN          NaN           0           0          NaN          NaN
# 103       NaN          NaN           0           0          NaN          NaN
# 985       NaN          NaN           0           0          NaN          NaN
# 554       NaN          NaN           0           0          NaN          NaN
# 706       NaN          NaN           0           0          NaN          NaN
# 1217      NaN          NaN           0           0          NaN          NaN
# 647       NaN          NaN           0           0          NaN          NaN
# 1001      NaN          NaN           0           0          NaN          NaN
# 737       NaN          NaN           0           0          NaN          NaN
# 260       NaN          NaN           0           0          NaN          NaN
# 372       NaN          NaN           0           0          NaN          NaN
#
#       BsmtFullBath  BsmtHalfBath BsmtQual  BsmtUnfSF  TotalBsmtSF
# Id
# 869              0             0      NaN          0            0
# 534              0             0      NaN          0            0
# 1050             0             0      NaN          0            0
# 533              0             0      NaN          0            0
# 157              0             0      NaN          0            0
# 779              0             0      NaN          0            0
# 91               0             0      NaN          0            0
# 393              0             0      NaN          0            0
# 1322             0             0      NaN          0            0
# 183              0             0      NaN          0            0
# 1049             0             0      NaN          0            0
# 750              0             0      NaN          0            0
# 363              0             0      NaN          0            0
# 1012             0             0      NaN          0            0
# 898              0             0      NaN          0            0
# 1233             0             0      NaN          0            0
# 343              0             0      NaN          0            0
# 521              0             0      NaN          0            0
# 1091             0             0      NaN          0            0
# 18               0             0      NaN          0            0
# 1413             0             0      NaN          0            0
# 40               0             0      NaN          0            0
# 1046             0             0      NaN          0            0
# 895              0             0      NaN          0            0
# 1036             0             0      NaN          0            0
# 1180             0             0      NaN          0            0
# 1219             0             0      NaN          0            0
# 103              0             0      NaN          0            0
# 985              0             0      NaN          0            0
# 554              0             0      NaN          0            0
# 706              0             0      NaN          0            0
# 1217             0             0      NaN          0            0
# 647              0             0      NaN          0            0
# 1001             0             0      NaN          0            0
# 737              0             0      NaN          0            0
# 260              0             0      NaN          0            0
# 372              0             0      NaN          0            0

# %%
bsmt_feat_all_nan.shape
# Out:
# (37, 11)

# %%
qual = list(df.loc[:, df.dtypes == 'object'].columns.values)
qual
# Out:
# ['MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'SaleType',
#  'SaleCondition']

# %%
# Fillinf the mising value in bsmt features
for i in bsmt_col:
    if i in qual:
        bsmt_feat_all_nan[i] = bsmt_feat_all_nan[i].replace(np.nan, 'NA') # replace the NAN value by 'NA'
    else:
        bsmt_feat_all_nan[i] = bsmt_feat_all_nan[i].replace(np.nan, 0) # replace the NAN value inplace of 0

bsmt_feat.update(bsmt_feat_all_nan) # update bsmt_feat df by bsmt_feat_all_nan
df.update(bsmt_feat_all_nan) # update df by bsmt_feat_all_nan

"""
>>> df = pd.DataFrame({'A': [1, 2, 3],
...                    'B': [400, 500, 600]})
>>> new_df = pd.DataFrame({'B': [4, 5, 6],
...                        'C': [7, 8, 9]})
>>> df.update(new_df)
>>> df
   A  B
0  1  4
1  2  5
2  3  6
"""
# Out:
# C:\Users\Visual singh\AppData\Local\Temp\ipykernel_16044\2795227153.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bsmt_feat_all_nan[i] = bsmt_feat_all_nan[i].replace(np.nan, 'NA') # replace the NAN value by 'NA'
# C:\Users\Visual singh\AppData\Local\Temp\ipykernel_16044\2795227153.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bsmt_feat_all_nan[i] = bsmt_feat_all_nan[i].replace(np.nan, 0) # replace the NAN value inplace of 0
# C:\Users\Visual singh\AppData\Local\Temp\ipykernel_16044\2795227153.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bsmt_feat.update(bsmt_feat_all_nan) # update bsmt_feat df by bsmt_feat_all_nan
# "\n>>> df = pd.DataFrame({'A': [1, 2, 3],\n...                    'B': [400, 500, 600]})\n>>> new_df = pd.DataFrame({'B': [4, 5, 6],\n...                        'C': [7, 8, 9]})\n>>> df.update(new_df)\n>>> df\n   A  B\n0  1  4\n1  2  5\n2  3  6\n"

# %%
bsmt_feat = bsmt_feat[bsmt_feat.isin([np.nan]).any(axis=1)]
bsmt_feat
# Out:
#     BsmtCond BsmtExposure  BsmtFinSF1  BsmtFinSF2 BsmtFinType1 BsmtFinType2  \
# Id
# 333       TA           No      1124.0       479.0          GLQ          NaN
# 949       TA          NaN         0.0         0.0          Unf          Unf
#
#      BsmtFullBath  BsmtHalfBath BsmtQual  BsmtUnfSF  TotalBsmtSF
# Id
# 333           1.0           0.0       Gd     1603.0       3206.0
# 949           0.0           0.0       Gd      936.0        936.0

# %%
bsmt_feat.shape
# Out:
# (2, 11)

# %%
print(df['BsmtFinSF2'].max())
print(df['BsmtFinSF2'].min())
# Out:
# 1474.0
# 0.0

# %%
pd.cut(range(0,1526),5) # create a bucket
# Out:
# [(-1.525, 305.0], (-1.525, 305.0], (-1.525, 305.0], (-1.525, 305.0], (-1.525, 305.0], ..., (1220.0, 1525.0], (1220.0, 1525.0], (1220.0, 1525.0], (1220.0, 1525.0], (1220.0, 1525.0]]
# Length: 1526
# Categories (5, interval[float64, right]): [(-1.525, 305.0] < (305.0, 610.0] < (610.0, 915.0] < (915.0, 1220.0] < (1220.0, 1525.0]]

# %%
df_slice = df[(df['BsmtFinSF2'] >= 305) & (df['BsmtFinSF2'] <= 610)]
df_slice
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# Id
# 1309          20       RM        100.0    12000   Pave      Reg         Lvl
# 494           20       RL         70.0     7931   Pave      Reg         Lvl
# 932           20       RL         70.0     9100   Pave      Reg         Lvl
# 843           80       RL         82.0     9020   Pave      Reg         Lvl
# 27            20       RL         60.0     7200   Pave      Reg         Lvl
# 1216          20       RL         99.0     7094   Pave      IR1         Lvl
# 1153          20       RL         90.0    14115   Pave      IR1         Lvl
# 208           20       RL          NaN    12493   Pave      IR1         Lvl
# 353           50       RL         60.0     9084   Pave      Reg         Lvl
# 941           90       RL         55.0    12640   Pave      IR1         Lvl
# 909           20       RL          NaN     8885   Pave      IR1         Low
# 333           20       RL         85.0    10655   Pave      IR1         Lvl
# 415           60       RL         59.0    11228   Pave      IR2         Lvl
# 74            20       RL         85.0    10200   Pave      Reg         Lvl
# 174           20       RL         80.0    10197   Pave      IR1         Lvl
# 1165          80       RL          NaN    16157   Pave      IR1         Lvl
# 630           80       RL         82.0     9020   Pave      Reg         Lvl
# 755           20       RL         61.0     7930   Pave      Reg         Lvl
# 857           80       RL          NaN    10970   Pave      IR1         Low
# 505          160       RL         24.0     2308   Pave      Reg         Lvl
# 1260          20       RL         65.0     9750   Pave      Reg         Lvl
# 1387          60       RL         80.0    16692   Pave      IR1         Lvl
# 1026          20       RL         70.0     7700   Pave      Reg         Lvl
# 920           20       RL         87.0    11029   Pave      IR1         Lvl
# 892           60       RL         70.0    11184   Pave      Reg         Lvl
# 178           50       RL          NaN    13650   Pave      Reg         Lvl
# 436           60       RL         43.0    10667   Pave      IR2         Lvl
# 1273          20       RL          NaN    13526   Pave      IR1         Lvl
# 615          180       RM         21.0     1491   Pave      Reg         Lvl
# 463           20       RL         60.0     8281   Pave      IR1         Lvl
# 698           20       RL         57.0     6420   Pave      IR1         Lvl
# 811           20       RL         78.0    10140   Pave      Reg         Lvl
# 254           80       RL         85.0     9350   Pave      Reg         Lvl
# 356           20       RL        105.0    11249   Pave      IR2         Lvl
# 634           20       RL         80.0     9250   Pave      Reg         Lvl
# 587           30       RL         55.0    10267   Pave      Reg         Lvl
# 1397          20       RL          NaN    57200   Pave      IR1         Bnk
# 1025          20       RL          NaN    15498   Pave      IR1         Lvl
# 1388          50       RM         60.0     8520   Pave      Reg         Lvl
# 650          180       RM         21.0     1936   Pave      Reg         Lvl
# 1425          20       RL          NaN     9503   Pave      Reg         Lvl
# 391           50       RL         50.0     8405   Pave      Reg         Lvl
# 1378          50       RL         60.0    10998   Pave      Reg         Lvl
# 1222          20       RL         55.0     8250   Pave      Reg         Lvl
# 834           20       RL        100.0    10004   Pave      Reg         Lvl
# 945           20       RL          NaN    14375   Pave      IR1         Lvl
# 1399          50       RL         60.0     7200   Pave      Reg         Lvl
# 1060          50       RL          NaN    11275   Pave      IR1         HLS
# 1174          50       RL        138.0    18030   Pave      IR1         Bnk
# 807           80       RL         75.0     9750   Pave      Reg         Lvl
# 441           20       RL        105.0    15431   Pave      Reg         Lvl
# 578           80       RL         96.0    11777   Pave      IR1         Lvl
# 1014          30       RM         60.0     7200   Pave      Reg         Lvl
# 1221          20       RL         66.0     7800   Pave      IR1         Lvl
# 45            20       RL         70.0     7945   Pave      Reg         Lvl
# 44            20       RL          NaN     9200   Pave      IR1         Lvl
#
#      Utilities LotConfig LandSlope Neighborhood Condition1 Condition2  \
# Id
# 1309    AllPub    Inside       Gtl      OldTown       Norm       Norm
# 494     AllPub    Inside       Gtl        NAmes       Norm       Norm
# 932     AllPub    Inside       Gtl        NAmes       Norm       Norm
# 843     AllPub    Inside       Gtl        NAmes       Norm       Norm
# 27      AllPub    Corner       Gtl        NAmes       Norm       Norm
# 1216    AllPub    Inside       Gtl       Sawyer       Norm       Norm
# 1153    AllPub    Inside       Gtl      Crawfor       Norm       Norm
# 208     AllPub    Inside       Gtl        NAmes       Norm       Norm
# 353     AllPub    Inside       Gtl      Edwards     Artery       Norm
# 941     AllPub    Inside       Gtl      Mitchel       Norm       Norm
# 909     AllPub    Inside       Mod      Mitchel       Norm       Norm
# 333     AllPub    Inside       Gtl      NridgHt       Norm       Norm
# 415     AllPub   CulDSac       Gtl      SawyerW       Norm       Norm
# 74      AllPub    Inside       Gtl        NAmes       Norm       Norm
# 174     AllPub    Inside       Gtl        NAmes       Norm       Norm
# 1165    AllPub       FR2       Gtl      Veenker      Feedr       Norm
# 630     AllPub    Corner       Gtl        NAmes      Feedr       Norm
# 755     AllPub    Inside       Gtl        NAmes       Norm       Norm
# 857     AllPub    Inside       Mod      CollgCr       Norm       Norm
# 505     AllPub    Inside       Gtl      NPkVill       Norm       Norm
# 1260    AllPub       FR2       Gtl        NAmes       Norm       Norm
# 1387    AllPub    Inside       Gtl       NWAmes       RRAn       Norm
# 1026    AllPub    Corner       Gtl      CollgCr       Norm       Norm
# 920     AllPub    Corner       Gtl        NAmes       Norm       Norm
# 892     AllPub    Inside       Gtl       Sawyer       Norm       Norm
# 178     AllPub    Inside       Gtl       Sawyer       Norm       Norm
# 436     AllPub   CulDSac       Gtl      CollgCr       PosN       Norm
# 1273    AllPub   CulDSac       Gtl       Sawyer       Norm       Norm
# 615     AllPub    Inside       Gtl      MeadowV       Norm       Norm
# 463     AllPub    Inside       Gtl       Sawyer       Norm       Norm
# 698     AllPub    Inside       Gtl      Edwards       Norm       Norm
# 811     AllPub    Inside       Gtl       NWAmes       Norm       Norm
# 254     AllPub    Inside       Gtl        NAmes       Norm       Norm
# 356     AllPub    Inside       Gtl      CollgCr       Norm       Norm
# 634     AllPub    Corner       Gtl        NAmes       Norm       Norm
# 587     AllPub    Inside       Gtl      BrkSide       RRAn       Norm
# 1397    AllPub    Inside       Sev       Timber       Norm       Norm
# 1025    AllPub    Corner       Gtl       Timber       Norm       Norm
# 1388    AllPub    Inside       Gtl      OldTown     Artery       Norm
# 650     AllPub    Inside       Gtl      MeadowV       Norm       Norm
# 1425    AllPub    Inside       Gtl        NAmes       Norm       Norm
# 391     AllPub    Inside       Gtl      Edwards       Norm       Norm
# 1378    AllPub    Inside       Gtl      Edwards       Norm       Norm
# 1222    AllPub    Inside       Gtl       Sawyer      Feedr       Norm
# 834     AllPub    Inside       Gtl        NAmes       Norm       Norm
# 945     NoSeWa   CulDSac       Gtl       Timber       Norm       Norm
# 1399    AllPub    Inside       Gtl        NAmes       Norm       Norm
# 1060    AllPub    Corner       Mod      Crawfor       Norm       Norm
# 1174    AllPub    Inside       Gtl      ClearCr       Norm       Norm
# 807     AllPub    Inside       Gtl        NAmes       Norm       Norm
# 441     AllPub    Inside       Gtl      NridgHt       Norm       Norm
# 578     AllPub    Inside       Gtl       Sawyer       Norm       Norm
# 1014    AllPub    Inside       Gtl      OldTown       Norm       Norm
# 1221    AllPub    Inside       Gtl        NAmes       Norm       Norm
# 45      AllPub    Inside       Gtl        NAmes       Norm       Norm
# 44      AllPub   CulDSac       Gtl      CollgCr       Norm       Norm
#
#      BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# Id
# 1309     1Fam     1Story            5            7       1948          2005
# 494      1Fam     1Story            5            6       1960          1960
# 932      1Fam     1Story            5            6       1965          1965
# 843      1Fam       SLvl            6            7       1966          1966
# 27       1Fam     1Story            5            7       1951          2000
# 1216     1Fam     1Story            5            5       1966          1966
# 1153     1Fam     1Story            6            7       1956          2004
# 208      1Fam     1Story            4            5       1960          1960
# 353      1Fam     1.5Fin            5            6       1941          1950
# 941    Duplex     1Story            6            5       1976          1976
# 909      1Fam     1Story            5            5       1983          1983
# 333      1Fam     1Story            8            5       2003          2004
# 415      1Fam     2Story            7            5       1993          1993
# 74       1Fam     1Story            5            7       1954          2003
# 174      1Fam     1Story            6            5       1961          1961
# 1165     1Fam       SLvl            5            7       1978          1978
# 630      1Fam       SLvl            6            5       1964          1964
# 755      1Fam     1Story            6            8       1969          2005
gable  CompShg     Wd Sdng     Wd Sdng    BrkFace       104.0
# 174      Gable  CompShg     WdShing     Wd Shng     BrkCmn       491.0
# 1165     Gable  CompShg     Plywood     Plywood       None         0.0
# 630      Gable  WdShngl     Plywood     Wd Sdng    BrkFace       259.0
# 755      Gable  CompShg     Plywood     Plywood       None         0.0
# 857      Gable  CompShg     Plywood     HdBoard       None         0.0
# 505      Gable  CompShg     Plywood     Brk Cmn       None         0.0
# 1260     Gable  CompShg     HdBoard     HdBoard       None         0.0
# 1387     Gable  CompShg     Plywood     Plywood    BrkFace       184.0
# 1026     Gable  CompShg     VinylSd     VinylSd       None         0.0
# 920        Hip  CompShg     MetalSd     MetalSd       None         0.0
# 892        Hip  CompShg     HdBoard     HdBoard    BrkFace        92.0
# 178      Gable  CompShg     MetalSd     MetalSd       None         0.0
# 436      Gable  CompShg     VinylSd     VinylSd       None         0.0
# 1273       Hip  CompShg     HdBoard     Plywood    BrkFace       114.0
# 615      Gable  CompShg     CemntBd     CmentBd       None         0.0
# 463      Gable  CompShg     MetalSd     MetalSd       None         0.0
# 698      Gable  CompShg     Wd Sdng     Wd Sdng       None         0.0
# 811        Hip  CompShg     HdBoard     HdBoard    BrkFace        99.0
# 254        Hip  CompShg     HdBoard     HdBoard    BrkFace       108.0
# 356      Gable  CompShg     VinylSd     VinylSd       None         0.0
# 634      Gable  CompShg     Wd Sdng     Wd Sdng       None         0.0
# 587      Gable  CompShg      Stucco     Wd Shng       None         0.0
# 1397     Gable  CompShg     Wd Sdng     Wd Sdng       None         0.0
# 1025       Hip  WdShake       Stone     HdBoard       None         0.0
# 1388     Gable  CompShg      Stucco      Stucco       None         0.0
# 650      Gable  CompShg     CemntBd     CmentBd       None         0.0
# 1425       Hip  CompShg     HdBoard     HdBoard       None         0.0
# 391      Gable  CompShg     MetalSd     MetalSd       None         0.0
# 1378     Gable  CompShg     Wd Sdng     Wd Sdng       None         0.0
# 1222       Hip  CompShg     HdBoard     HdBoard       None         0.0
# 834      Gable  CompShg     HdBoard     Plywood    BrkFace       180.0
# 945      Gable  CompShg     HdBoard     HdBoard    BrkFace       541.0
# 1399     Gable  CompShg     VinylSd     Wd Sdng       None         0.0
# 1060     Gable  CompShg     MetalSd     MetalSd    BrkFace       480.0
# 1174     Gable  CompShg     MetalSd     MetalSd       None         0.0
# 807      Gable  CompShg     VinylSd     VinylSd       None         0.0
# 441        Hip  CompShg     VinylSd     VinylSd      Stone       200.0
# 578      Gable  CompShg     VinylSd     VinylSd    BrkFace        97.0
# 1014       Hip  CompShg     MetalSd      Stucco       None         0.0
# 1221     Gable  CompShg     Wd Sdng     Wd Sdng       None         0.0
# 45       Gable  CompShg     BrkFace     Wd Sdng       None         0.0
# 44         Hip  CompShg     VinylSd     VinylSd       None         0.0
#
#      ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# Id
# 1309        TA        TA     CBlock       TA       TA           No
# 494         TA        TA     CBlock       TA       TA           No
# 932         TA        TA     CBlock       TA       TA           No
# 843         TA        TA     CBlock       TA       TA           Gd
# 27          TA        TA     CBlock       TA       TA           Mn
# 1216        TA        TA     CBlock       TA       TA           No
# 1153        TA        TA      PConc       TA       TA           No
# 208         TA        TA      PConc       TA       TA           No
# 353         TA        TA     CBlock       TA       Fa           Mn
# 941         TA        TA     CBlock       TA       TA           Gd
# 909         TA        TA     CBlock       Gd       TA           Av
# 333         Gd        TA      PConc       Gd       TA           No
# 415         Gd        TA      PConc       Gd       TA           No
# 74          TA        TA     CBlock       TA       TA           No
# 174         TA        TA     CBlock       TA       TA           No
# 1165        TA        TA      PConc       Gd       TA           Gd
# 630         TA        TA     CBlock       TA       TA           Gd
# 755         TA        TA     CBlock       TA       TA           No
# 857         TA        TA     CBlock       Gd       Gd           Gd
# 505         TA        TA     CBlock       TA       TA           No
# 1260        TA        TA     CBlock       Gd       TA           No
# 1387        TA        TA     CBlock       Gd       TA           No
# 1026        TA        TA     CBlock       TA       TA           No
# 920         Ex        TA     CBlock       Gd       TA           No
# 892         TA        TA     CBlock       TA       TA           No
# 178         Gd        Gd     CBlock       TA       TA           No
# 436         Gd        TA      PConc       Gd       TA           Av
# 1273        TA        TA     CBlock       TA       TA           No
# 615         TA        TA     CBlock       Gd       TA           Av
# 463         TA        TA     CBlock       TA       TA           No
# 698         TA        TA      PConc       Ex       Gd           Mn
# 811         TA        TA     CBlock       TA       TA           No
# 254         TA        TA     CBlock       Gd       TA           Gd
# 356         Gd        Gd      PConc       Gd       Gd           No
# 634         TA        TA     CBlock       TA       TA           No
# 587         TA        Gd     BrkTil       TA       Gd           Mn
# 1397        TA        TA     CBlock       TA       TA           Av
# 1025        Gd        TA     CBlock       Gd       TA           Av
# 1388        TA        Gd     BrkTil       TA       TA           No
# 650         TA        TA     CBlock       Gd       TA           Av
# 1425        TA        TA     CBlock       TA       TA           No
# 391         TA        TA     BrkTil       TA       Gd           No
# 1378        TA        TA     CBlock       TA       TA           No
# 1222        TA        TA     CBlock       TA       TA           No
# 834         TA        TA     CBlock       TA       TA           No
# 945         TA        TA     CBlock       TA       TA           No
# 1399        TA        TA     CBlock       TA       TA           No
# 1060        TA        TA     CBlock       TA       TA           Mn
# 1174        TA        TA     CBlock       TA       TA           No
# 807         TA        TA      PConc       TA       TA           Av
# 441         Ex        TA      PConc       Ex       TA           Gd
# 578         TA        TA     CBlock       TA       TA           Av
# 1014        TA        TA     BrkTil       TA       TA           No
# 1221        TA        TA     CBlock       TA       TA           No
# 45          TA        TA     CBlock       TA       TA           No
# 44          TA        TA     CBlock       Gd       TA           Av
#
#      BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  \
# Id
# 1309          GLQ       144.0          ALQ       608.0      172.0
# 494           BLQ       374.0          LwQ       532.0      363.0
# 932           BLQ       338.0          Rec       466.0      121.0
# 843           Rec       312.0          ALQ       539.0      276.0
# 27            BLQ       234.0          Rec       486.0      180.0
# 1216          Rec       180.0          LwQ       374.0      340.0
# 1153          ALQ       296.0          GLQ       547.0      230.0
# 208           ALQ       419.0          Rec       306.0      375.0
# 353           LwQ       236.0          Rec       380.0        0.0
# 941           Rec       936.0          LwQ       396.0      396.0
# 909           BLQ       301.0          ALQ       324.0      239.0
# 333           GLQ      1124.0          NaN       479.0     1603.0
# 415           BLQ        50.0          GLQ       531.0      499.0
# 74            ALQ       320.0          BLQ       362.0      404.0
# 174           ALQ       288.0          Rec       374.0      700.0
# 1165          ALQ       680.0          Rec       391.0      289.0
# 630           GLQ       624.0          Rec       336.0      288.0
# 755           GLQ       439.0          LwQ       472.0      115.0
# 755              0       1026           1.0           0.0         1         0
# 857              0       1026           1.0           0.0         1         0
# 505              0       1322           0.0           1.0         2         1
# 1260             0       1054           1.0           0.0         1         1
# 1387             0       2784           1.0           0.0         3         1
# 1026             0        882           1.0           0.0         1         0
# 920              0       1414           1.0           0.0         1         0
# 892              0       1683           0.0           0.0         2         1
# 178              0       1920           1.0           0.0         2         0
# 436              0       1661           1.0           0.0         2         1
# 1273             0        935           1.0           0.0         1         0
# 615              0        630           1.0           0.0         1         0
# 463              0        864           0.0           0.0         1         0
# 698              0       1148           0.0           1.0         1         0
# 811              0       1309           1.0           0.0         1         1
# 254              0       1302           0.0           1.0         2         0
# 356              0       1200           1.0           0.0         2         0
# 634              0       1056           0.0           1.0         1         0
# 587              0        838           1.0           0.0         1         0
# 1397             0       1687           1.0           0.0         1         0
# 1025             0       2898           1.0           0.0         2         0
# 1388             0       2526           0.0           0.0         2         0
# 650              0        630           1.0           0.0         1         0
# 1425             0       1344           1.0           0.0         1         0
# 391              0       1367           1.0           0.0         1         0
# 1378             0       1604           0.0           0.0         2         0
# 1222             0       1211           0.0           0.0         1         0
# 834              0       1516           0.0           0.0         1         1
# 945              0       1344           0.0           1.0         1         0
# 1399             0       1904           1.0           0.0         1         1
# 1060             0       1991           0.0           0.0         1         1
# 1174           479       3086           0.0           0.0         3         0
# 807              0        980           0.0           0.0         2         0
# 441              0       2402           1.0           0.0         2         0
# 578              0       1320           1.0           0.0         1         0
# 1014             0       1022           1.0           0.0         1         0
# 1221             0        912           0.0           0.0         1         0
# 45               0       1150           1.0           0.0         1         0
# 44               0        938           1.0           0.0         1         0
#
#       BedroomAbvGr  KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  \
# Id
# 1309             2             1          Gd             6        Typ
# 494              3             1          TA             6        Typ
# 932              2             1          TA             5        Typ
# 843              3             1          TA             6        Typ
# 27               3             1          Gd             5        Typ
# 1216             3             1          TA             5        Typ
# 1153             2             1          Ex             6        Typ
# 208              3             1          TA             6        Typ
# 353              3             1          TA             5        Typ
# 941              4             2          TA             8        Typ
# 909              2             1          TA             5        Typ
# 333              3             1          Gd             7        Typ
# 415              3             1          Gd             9        Typ
# 74               3             1          TA             6        Typ
# 174              3             1          TA             6        Typ
# 1165             2             1          Gd             5        Typ
# 630              3             1          TA             6        Typ
# 755              3             1          Gd             5        Typ
# 857              3             1          TA             5        Typ
# 505              3             1          TA             6        Typ
# 1260             3             1          TA             6        Typ
# 1387             5             1          Gd            12        Typ
# 1026             3             1          TA             5        Typ
# 920              3             1          TA             6       Min1
# 892              3             1          TA             7        Typ
# 178              4             1          Gd             8        Typ
# 436              3             1          Gd             6        Typ
# 1273             3             1          TA             5        Typ
# 615              1             1          TA             3        Typ
# 463              3             1          TA             5        Typ
# 698              2             1          TA             6        Typ
# 811              3             1          Gd             5        Typ
# 254              3             1          Gd             7       Min1
# 356              3             1          Gd             6        Typ
# 634              3             1          TA             6        Typ
# 587              2             1          Fa             5        Typ
# 1397             3             1          TA             7       Min1
# 1025             2             1          Gd            10        Typ
# 1388             5             1          Gd            10        Typ
# 650              1             1          TA             3        Typ
arageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# Id
# 1309         TA         TA          Y           0           36              0
# 494          TA         TA          Y           0            0              0
# 932          TA         TA          Y           0            0              0
# 843          Gd         Gd          Y           0          129              0
# 27           TA         TA          Y         222           32              0
# 1216         TA         TA          Y           0            0              0
# 1153         TA         TA          Y           0            0            280
# 208          TA         TA          Y         355            0              0
# 353          TA         Fa          Y          48            0              0
# 941          TA         TA          Y          40            0              0
# 909          TA         TA          Y         164            0              0
# 333          TA         TA          Y           0            0              0
# 415          TA         TA          Y         196          187              0
# 74           TA         TA          Y           0            0              0
# 174          TA         TA          Y           0           20              0
# 1165         TA         TA          Y         168          180              0
# 630          TA         TA          Y         176            0              0
# 755          TA         TA          Y         171           48              0
# 857          TA         Fa          Y           0            0             34
# 505          TA         TA          Y         260            0              0
# 1260         TA         TA          Y         180            0              0
# 1387         TA         TA          Y           0          112              0
# 1026         TA         TA          Y          96            0              0
# 920          TA         TA          Y           0           51              0
# 892          TA         TA          Y         243            0              0
# 178          TA         TA          Y           0            0              0
# 436          TA         TA          Y         158           61              0
# 1273         TA         TA          Y         180            0              0
# 615         NaN        NaN          Y          96           24              0
# 463          TA         TA          Y           0            0            236
# 698          TA         TA          Y           0            0              0
# 811          TA         TA          Y         265            0              0
# 254          TA         TA          Y         333            0              0
# 356          TA         TA          Y           0           26              0
# 634          TA         TA          Y         390            0              0
# 587          TA         TA          N           0            0            112
# 1397         TA         TA          N           0            0             50
# 1025         TA         TA          Y           0           72            174
# 1388         TA         TA          Y          88           15              0
# 650         NaN        NaN          Y           0            0              0
# 1425         TA         TA          Y         316           28              0
# 391          TA         TA          Y           0          130            112
# 1378         TA         TA          Y           0           68              0
# 1222         TA         TA          Y           0           63              0
# 834          TA         TA          Y           0            0              0
# 945          TA         TA          Y           0          118              0
# 1399         TA         TA          Y           0            0            168
# 1060         TA         Fa          Y           0            0             19
# 1174        NaN        NaN          Y         122            0              0
# 807          TA         TA          Y          68            0              0
# 441          TA         TA          Y           0           72              0
# 578          TA         TA          Y         160           68            240
# 1014         TA         TA          Y           0           30            226
# 1221         TA         TA          Y           0            0              0
# 45           TA         TA          Y           0            0              0
# 44           TA         TA          Y         145            0              0
#
#       3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold SaleType  \
# Id
# 1309          0            0         0        0       5    2008       WD
# 494           0            0         0        0       6    2008       WD
# 932           0            0         0        0       7    2009       WD
# 843           0            0         0        0       5    2008       WD
# 27            0            0         0        0       5    2010       WD
# 1216          0            0         0        0       5    2007       WD
# 1153          0            0         0        0       7    2006       WD
# 208           0            0         0        0       4    2008       WD
# 353           0            0         0        0       3    2008    ConLw
# 941           0            0         0        0       7    2006       WD
# 909           0            0         0        0       6    2006       WD
# 333           0            0         0        0      10    2009       WD
# 415           0            0         0        0      12    2008       WD
# 74            0            0         0        0       5    2010       WD
# 174           0            0         0        0       6    2008      COD
# 1165          0            0         0        0       6    2007       WD
# 630           0            0         0        0       6    2008       WD
# 755           0            0         0        0       7    2009       WD
# 857           0            0         0        0      10    2008       WD
# 505           0            0         0        0       6    2009       WD
# 1260          0           80         0        0       7    2008       WD
# 1387          0          440       519     2000       7    2006       WD
# 1026          0            0         0        0       3    2007       WD
# 920           0          190         0        0       5    2008       WD
# 892           0            0         0        0       7    2009       WD
# 178           0            0         0        0       7    2006       WD
# 436           0            0         0        0       4    2009    ConLw
# 1273          0            0         0        0      11    2006       WD
# 615           0            0         0        0       5    2010       WD
# 463           0            0         0        0      12    2009       WD
# 698           0            0         0        0       9    2006       WD
# 811           0            0       648        0       1    2006       WD
# 254           0            0         0        0      10    2007      CWD
# 356           0            0         0        0       8    2007       WD
# 634           0            0         0        0       7    2007       WD
# 587           0            0         0        0       5    2008       WD
# 1397          0            0         0        0       6    2010       WD
# 1025          0            0         0        0       5    2008      COD
# 1388          0            0         0        0       8    2007      CWD
# 650           0            0         0        0      12    2007       WD
# 1425          0            0         0        0       6    2007       WD
# 391           0            0         0        0       4    2008       WD
# 1378          0            0         0        0       7    2009       WD
# 1222          0            0         0        0       8    2008       WD
# 834           0          152         0        0       2    2009       WD
# 945           0          233         0        0       1    2009      COD
# 1399          0            0         0        0       5    2009       WD
# 1060          0            0         0        0       3    2007       WD
# 1174          0            0         0        0       3    2007       WD
# 807           0            0         0        0      10    2006       WD
# 441           0          170         0        0       4    2009       WD
# 578           0            0         0        0       5    2006       WD
# 1014          0            0         0        0       6    2009       WD
# 1221          0            0         0        0      11    2006       WD
# 45            0            0         0        0       5    2006       WD
# 44            0            0         0        0       7    2008       WD
#
#      SaleCondition  SalePrice
# Id
# 1309        Normal   147000.0
# 494         Normal   155000.0
# 932         Normal   117500.0
# 843         Normal   174900.0
# 27          Normal   134800.0
# 1216        Normal   125000.0
# 1153       Abnorml   230000.0
# 208         Normal   141000.0
# 353         Normal    95000.0
# 941         Normal   150900.0
# 909         Normal   131000.0
# 333         Normal   284000.0
# 415         Normal   228000.0
# 74          Normal   144900.0
# 174         Normal   163000.0
# 1165        Normal   194000.0
# 630         Normal   168500.0
# 755         Normal   156000.0
# 857         Normal   147000.0
# 505         Normal   147000.0
# 1260        Normal   151000.0
# 1387        Normal   250000.0
# 1026        Normal   112500.0
# 920         Normal   176500.0
# 892         Normal   172500.0
# 178         Normal   172500.0
# 436         Normal   212000.0
# 1273        Normal   137000.0
# 615         Normal    75500.0
# 463         Normal    62383.0
# 698         Normal   123500.0
# 811         Normal   181000.0
# 254         Normal   158000.0
# 356         Normal   177500.0
# 634         Normal   139400.0
# 587         Normal   130000.0
# 1397        Normal   160000.0
# 1025       Abnorml   287000.0
# 1388        Family   136000.0
# 650         Normal        NaN
# 1425        Normal        NaN
# 391         Normal        NaN
# 1378        Normal        NaN
# 1222        Normal        NaN
# 834         Normal        NaN
# 945        Abnorml        NaN
# 1399        Normal        NaN
# 1060        Normal        NaN
# 1174        Normal        NaN
# 807         Normal        NaN
# 441         Normal        NaN
# 578        Abnorml        NaN
# 1014        Normal        NaN
# 1221       Abnorml        NaN
# 45          Normal        NaN
# 44          Normal        NaN

# %%
bsmt_feat.at[333,'BsmtFinType2'] = df_slice['BsmtFinType2'].mode()[0]

# %%
bsmt_feat
# Out:
#     BsmtCond BsmtExposure  BsmtFinSF1  BsmtFinSF2 BsmtFinType1 BsmtFinType2  \
# Id
# 333       TA           No      1124.0       479.0          GLQ          LwQ
# 949       TA          NaN         0.0         0.0          Unf          Unf
#
#      BsmtFullBath  BsmtHalfBath BsmtQual  BsmtUnfSF  TotalBsmtSF
# Id
# 333           1.0           0.0       Gd     1603.0       3206.0
# 949           0.0           0.0       Gd      936.0        936.0

# %%
bsmt_feat['BsmtExposure'] = bsmt_feat['BsmtExposure'].replace(np.nan, df[df['BsmtQual'] =='Gd']['BsmtExposure'].mode()[0])
# Out:
# C:\Users\Visual singh\AppData\Local\Temp\ipykernel_16044\4112458698.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bsmt_feat['BsmtExposure'] = bsmt_feat['BsmtExposure'].replace(np.nan, df[df['BsmtQual'] =='Gd']['BsmtExposure'].mode()[0])

# %%
bsmt_feat['BsmtCond'] = bsmt_feat['BsmtCond'].replace(np.nan, df['BsmtCond'].mode()[0])
bsmt_feat['BsmtQual'] = bsmt_feat['BsmtQual'].replace(np.nan, df['BsmtQual'].mode()[0])
# Out:
# C:\Users\Visual singh\AppData\Local\Temp\ipykernel_16044\1418674735.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bsmt_feat['BsmtCond'] = bsmt_feat['BsmtCond'].replace(np.nan, df['BsmtCond'].mode()[0])
# C:\Users\Visual singh\AppData\Local\Temp\ipykernel_16044\1418674735.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bsmt_feat['BsmtQual'] = bsmt_feat['BsmtQual'].replace(np.nan, df['BsmtQual'].mode()[0])

# %%
df.update(bsmt_feat)

# %%
bsmt_feat.isnull().sum()
# Out:
# BsmtCond        0
# BsmtExposure    0
# BsmtFinSF1      0
# BsmtFinSF2      0
# BsmtFinType1    0
# BsmtFinType2    0
# BsmtFullBath    0
# BsmtHalfBath    0
# BsmtQual        0
# BsmtUnfSF       0
# TotalBsmtSF     0
# dtype: int64

# %% [markdown]
# # Handling missing value of Garage feature

# %%
df.columns[df.isnull().any()]
# Out:
# Index(['LotFrontage', 'MasVnrType', 'MasVnrArea', 'Electrical', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageQual', 'GarageCond', 'SalePrice'],
#       dtype='object')

# %%
garage_col = ['GarageArea', 'GarageCars', 'GarageCond', 'GarageFinish', 'GarageQual', 'GarageType', 'GarageYrBlt',]
garage_feat = df[garage_col]
garage_feat = garage_feat[garage_feat.isnull().any(axis=1)]
garage_feat
# Out:
#       GarageArea  GarageCars GarageCond GarageFinish GarageQual GarageType  \
# Id
# 534            0           0        NaN          NaN        NaN        NaN
# 126            0           0        NaN          NaN        NaN        NaN
# 1327           0           0        NaN          NaN        NaN        NaN
# 141            0           0        NaN          NaN        NaN        NaN
# 149            0           0        NaN          NaN        NaN        NaN
# 308            0           0        NaN          NaN        NaN        NaN
# 166            0           0        NaN          NaN        NaN        NaN
# 827            0           0        NaN          NaN        NaN        NaN
# 1326           0           0        NaN          NaN        NaN        NaN
# 536            0           0        NaN          NaN        NaN        NaN
# 1235           0           0        NaN          NaN        NaN        NaN
# 621            0           0        NaN          NaN        NaN        NaN
# 242            0           0        NaN          NaN        NaN        NaN
# 1258           0           0        NaN          NaN        NaN        NaN
# 1350           0           0        NaN          NaN        NaN        NaN
# 442            0           0        NaN          NaN        NaN        NaN
# 90             0           0        NaN          NaN        NaN        NaN
# 109            0           0        NaN          NaN        NaN        NaN
#
#       GarageYrBlt
# Id
# 534           NaN
# 126           NaN
# 1327          NaN
# 141           NaN
# 149           NaN
# 308           NaN
# 166           NaN
# 827           NaN
# 1326          NaN
# 536           NaN
# 1235          NaN
# 164           NaN
# 1144          NaN
# 465           NaN
# 1010          NaN
# 922           NaN
# 969           NaN
# 435           NaN
# 156           NaN
# 387           NaN
# 394           NaN
# 1012          NaN
# 637           NaN
# 1450          NaN
# 1324          NaN
# 977           NaN
# 639           NaN
# 1454          NaN
# 211           NaN
# 1132          NaN
# 636           NaN
# 251           NaN
# 751           NaN
# 1138          NaN
# 1220          NaN
# 844           NaN
# 785           NaN
# 100           NaN
# 1097          NaN
# 711           NaN
# 288           NaN
# 89            NaN
# 739           NaN
# 292           NaN
# 614           NaN
# 615           NaN
# 376           NaN
# 1031          NaN
# 521           NaN
# 1039          NaN
# 955           NaN
# 496           NaN
# 563           NaN
# 79            NaN
# 199           NaN
# 40            NaN
# 1338          NaN
# 961           NaN
# 1180          NaN
# 1219          NaN
# 583           NaN
# 1284          NaN
# 971           NaN
# 943           NaN
# 650           NaN
# 1408          NaN
# 706           NaN
# 1451          NaN
# 49            NaN
# 1124          NaN
# 1174          NaN
# 432           NaN
# 128           NaN
# 529           NaN
# 621           NaN
# 242           NaN
# 1258          NaN
# 1350          NaN
# 442           NaN
# 90            NaN
# 109           NaN

# %%
garage_feat.shape
# Out:
# (81, 7)

# %%
garage_feat_all_nan = garage_feat[(garage_feat.isnull() | garage_feat.isin([0])).all(1)]
garage_feat_all_nan.shape
# Out:
# (81, 7)

# %%
for i in garage_feat:
    if i in qual:
        garage_feat_all_nan[i] = garage_feat_all_nan[i].replace(np.nan, 'NA')
    else:
        garage_feat_all_nan[i] = garage_feat_all_nan[i].replace(np.nan, 0)
        
garage_feat.update(garage_feat_all_nan)
df.update(garage_feat_all_nan)

# %%
garage_feat = garage_feat[garage_feat.isnull().any(axis=1)]
garage_feat
# Out:
# Empty DataFrame
# Columns: [GarageArea, GarageCars, GarageCond, GarageFinish, GarageQual, GarageType, GarageYrBlt]
# Index: []

# %%
for i in garage_col:
    garage_feat[i] = garage_feat[i].replace(np.nan, df[df['GarageType'] == 'Detchd'][i].mode()[0])

# %%
garage_feat.isnull().any()
# Out:
# GarageArea      False
# GarageCars      False
# GarageCond      False
# GarageFinish    False
# GarageQual      False
# GarageType      False
# GarageYrBlt     False
# dtype: bool

# %%
df.update(garage_feat)

# %% [markdown]
# ## Handling missing value of remain feature

# %%
df.columns[df.isnull().any()]
# Out:
# Index(['LotFrontage', 'MasVnrType', 'MasVnrArea', 'Electrical', 'SalePrice'], dtype='object')

# %%
df['Electrical'] = df['Electrical'].fillna(df['Electrical'].mode()[0])
df['Exterior1st'] = df['Exterior1st'].fillna(df['Exterior1st'].mode()[0])
df['Exterior2nd'] = df['Exterior2nd'].fillna(df['Exterior2nd'].mode()[0])
df['Functional'] = df['Functional'].fillna(df['Functional'].mode()[0])
df['KitchenQual'] = df['KitchenQual'].fillna(df['KitchenQual'].mode()[0])
df['MSZoning'] = df['MSZoning'].fillna(df['MSZoning'].mode()[0])
df['SaleType'] = df['SaleType'].fillna(df['SaleType'].mode()[0])
df['Utilities'] = df['Utilities'].fillna(df['Utilities'].mode()[0])
df['MasVnrType'] = df['MasVnrType'].fillna(df['MasVnrType'].mode()[0])

# %%
df.columns[df.isnull().any()]
# Out:
# Index(['LotFrontage', 'MasVnrArea', 'SalePrice'], dtype='object')

# %%
df[df['MasVnrArea'].isnull() == True]['MasVnrType'].unique()
# Out:
# array(['None'], dtype=object)

# %%
df.loc[(df['MasVnrType'] == 'None') & (df['MasVnrArea'].isnull() == True), 'MasVnrArea'] = 0

# %%
df.isnull().sum()/df.shape[0] * 100
# Out:
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.739726
# LotArea           0.000000
# Street            0.000000
# LotShape          0.000000
# LandContour       0.000000
# Utilities         0.000000
# LotConfig         0.000000
# LandSlope         0.000000
# Neighborhood      0.000000
# Condition1        0.000000
# Condition2        0.000000
# BldgType          0.000000
# HouseStyle        0.000000
# OverallQual       0.000000
# OverallCond       0.000000
# YearBuilt         0.000000
# YearRemodAdd      0.000000
# RoofStyle         0.000000
# RoofMatl          0.000000
# Exterior1st       0.000000
# Exterior2nd       0.000000
# MasVnrType        0.000000
# MasVnrArea        0.000000
# ExterQual         0.000000
# ExterCond         0.000000
# Foundation        0.000000
# BsmtQual          0.000000
# BsmtCond          0.000000
# BsmtExposure      0.000000
# BsmtFinType1      0.000000
# BsmtFinSF1        0.000000
# BsmtFinType2      0.000000
# BsmtFinSF2        0.000000
# BsmtUnfSF         0.000000
# TotalBsmtSF       0.000000
# Heating           0.000000
# HeatingQC         0.000000
# CentralAir        0.000000
# Electrical        0.000000
# 1stFlrSF          0.000000
# 2ndFlrSF          0.000000
# LowQualFinSF      0.000000
# GrLivArea         0.000000
# BsmtFullBath      0.000000
# BsmtHalfBath      0.000000
# FullBath          0.000000
# HalfBath          0.000000
# BedroomAbvGr      0.000000
# KitchenAbvGr      0.000000
# KitchenQual       0.000000
# TotRmsAbvGrd      0.000000
# Functional        0.000000
# Fireplaces        0.000000
# GarageType        0.000000
# GarageYrBlt       0.000000
# GarageFinish      0.000000
# GarageCars        0.000000
# GarageArea        0.000000
# GarageQual        0.000000
# GarageCond        0.000000
# PavedDrive        0.000000
# WoodDeckSF        0.000000
# OpenPorchSF       0.000000
# EnclosedPorch     0.000000
# 3SsnPorch         0.000000
# ScreenPorch       0.000000
# PoolArea          0.000000
# MiscVal           0.000000
# MoSold            0.000000
# YrSold            0.000000
# SaleType          0.000000
# SaleCondition     0.000000
# SalePrice        20.000000
# dtype: float64

# %% [markdown]
# ## Handling missing value of LotFrontage feature

# %%
lotconfig = ['Corner', 'Inside', 'CulDSac', 'FR2', 'FR3']
for i in lotconfig:
    df['LotFrontage'] = pd.np.where((df['LotFrontage'].isnull() == True) & (df['LotConfig'] == i) , df[df['LotConfig'] == i] ['LotFrontage'].mean(), df['LotFrontage'])
# Out:
# C:\Users\Visual singh\AppData\Local\Temp\ipykernel_16044\1305564009.py:3: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   df['LotFrontage'] = pd.np.where((df['LotFrontage'].isnull() == True) & (df['LotConfig'] == i) , df[df['LotConfig'] == i] ['LotFrontage'].mean(), df['LotFrontage'])

# %%
df.isnull().sum()
# Out:
# MSSubClass         0
# MSZoning           0
# LotFrontage        0
# LotArea            0
# Street             0
# LotShape           0
# LandContour        0
# Utilities          0
# LotConfig          0
# LandSlope          0
# Neighborhood       0
# Condition1         0
# Condition2         0
# BldgType           0
# HouseStyle         0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# RoofStyle          0
# RoofMatl           0
# Exterior1st        0
# Exterior2nd        0
# MasVnrType         0
# MasVnrArea         0
# ExterQual          0
# ExterCond          0
# Foundation         0
# BsmtQual           0
# BsmtCond           0
# BsmtExposure       0
# BsmtFinType1       0
# BsmtFinSF1         0
# BsmtFinType2       0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# Heating            0
# HeatingQC          0
# CentralAir         0
# Electrical         0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# KitchenQual        0
# TotRmsAbvGrd       0
# Functional         0
# Fireplaces         0
# GarageType         0
# GarageYrBlt        0
# GarageFinish       0
# GarageCars         0
# GarageArea         0
# GarageQual         0
# GarageCond         0
# PavedDrive         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice        292
# dtype: int64

# %% [markdown]
# ## Feature Transformation

# %%
df.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'GarageType', 'GarageYrBlt', 'GarageFinish',
#        'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive',
#        'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
# converting columns in str which have categorical nature but in int64
feat_dtype_convert = ['MSSubClass', 'YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']
for i in feat_dtype_convert:
    df[i] = df[i].astype(str)

# %%
df['MoSold'].unique() # MoSold = Month of sold
# Out:
# array([ 2, 10,  6,  1, 11,  5,  4,  7,  8,  3,  9, 12], dtype=int64)

# %%
# conver in month abbrevation
import calendar
df['MoSold'] = df['MoSold'].apply(lambda x : calendar.month_abbr[x])

# %%
df['MoSold'].unique()
# Out:
# array(['Feb', 'Oct', 'Jun', 'Jan', 'Nov', 'May', 'Apr', 'Jul', 'Aug',
#        'Mar', 'Sep', 'Dec'], dtype=object)

# %%
quan = list(df.loc[:, df.dtypes != 'object'].columns.values)

# %%
quan
# Out:
# ['LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'SalePrice']

# %%
len(quan)
# Out:
# 31

# %%
obj_feat = list(df.loc[:, df.dtypes == 'object'].columns.values)
obj_feat
# Out:
# ['MSSubClass',
#  'MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'YearBuilt',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'MoSold',
#  'YrSold',
#  'SaleType',
#  'SaleCondition']

# %% [markdown]
# ## Conver categorical code into order

# %%
from pandas.api.types import CategoricalDtype
df['BsmtCond'] = df['BsmtCond'].astype(CategoricalDtype(categories=['NA', 'Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes

# %%
df['BsmtCond'].unique()
# Out:
# array([3, 4, 2, 0, 1], dtype=int8)

# %%
df['BsmtExposure'] = df['BsmtExposure'].astype(CategoricalDtype(categories=['NA', 'Mn', 'Av', 'Gd'], ordered = True)).cat.codes

# %%
df['BsmtExposure'].unique()
# Out:
# array([-1,  3,  2,  1,  0], dtype=int8)

# %%
df['BsmtFinType1'] = df['BsmtFinType1'].astype(CategoricalDtype(categories=['NA', 'Unf', 'LwQ', 'Rec', 'BLQ','ALQ', 'GLQ'], ordered = True)).cat.codes
df['BsmtFinType2'] = df['BsmtFinType2'].astype(CategoricalDtype(categories=['NA', 'Unf', 'LwQ', 'Rec', 'BLQ','ALQ', 'GLQ'], ordered = True)).cat.codes
df['BsmtQual'] = df['BsmtQual'].astype(CategoricalDtype(categories=['NA', 'Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes
df['ExterQual'] = df['ExterQual'].astype(CategoricalDtype(categories=['Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes
df['ExterCond'] = df['ExterCond'].astype(CategoricalDtype(categories=['Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes
df['Functional'] = df['Functional'].astype(CategoricalDtype(categories=['Sal', 'Sev', 'Maj2', 'Maj1', 'Mod','Min2','Min1', 'Typ'], ordered = True)).cat.codes
df['GarageCond'] = df['GarageCond'].astype(CategoricalDtype(categories=['NA', 'Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes
df['GarageQual'] = df['GarageQual'].astype(CategoricalDtype(categories=['NA', 'Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes
df['GarageFinish'] = df['GarageFinish'].astype(CategoricalDtype(categories=['NA', 'Unf', 'RFn', 'Fin'], ordered = True)).cat.codes
df['HeatingQC'] = df['HeatingQC'].astype(CategoricalDtype(categories=['Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes
df['KitchenQual'] = df['KitchenQual'].astype(CategoricalDtype(categories=['Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes
df['PavedDrive'] = df['PavedDrive'].astype(CategoricalDtype(categories=['N', 'P', 'Y'], ordered = True)).cat.codes
df['Utilities'] = df['Utilities'].astype(CategoricalDtype(categories=['ELO', 'NASeWa', 'NASeWr', 'AllPub'], ordered = True)).cat.codes

# %%
df['Utilities'].unique()
# Out:
# array([ 3, -1], dtype=int8)

# %% [markdown]
# # Show skewness of feature with distplot

# %%
skewed_features = ['1stFlrSF',
 '2ndFlrSF',
 '3SsnPorch',
 'BedroomAbvGr',
 'BsmtFinSF1',
 'BsmtFinSF2',
 'BsmtFullBath',
 'BsmtHalfBath',
 'BsmtUnfSF',
 'EnclosedPorch',
 'Fireplaces',
 'FullBath',
 'GarageArea',
 'GarageCars',
 'GrLivArea',
 'HalfBath',
 'KitchenAbvGr',
 'LotArea',
 'LotFrontage',
 'LowQualFinSF',
 'MasVnrArea',
 'MiscVal',
 'OpenPorchSF',
 'PoolArea',
 'ScreenPorch',
 'TotRmsAbvGrd',
 'TotalBsmtSF',
 'WoodDeckSF']

# %%
quan == skewed_features
# Out:
# False

# %%
plt.figure(figsize=(25,20))
for i in range(len(skewed_features)):
    if i <= 28:
        plt.subplot(7,4,i+1)
        plt.subplots_adjust(hspace = 0.5, wspace = 0.5)
        ax = sns.distplot(df[skewed_features[i]])
        ax.legend(["Skewness: {:.2f}".format(df[skewed_features[i]].skew())], fontsize = 'xx-large')
# Out:
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df_back = df

# %%
# decrease the skewnwnes of the data
for i in skewed_features:
    df[i] = np.log(df[i] + 1)

# %%
plt.figure(figsize=(25,20))
for i in range(len(skewed_features)):
    if i <= 28:
        plt.subplot(7,4,i+1)
        plt.subplots_adjust(hspace = 0.5, wspace = 0.5)
        ax = sns.distplot(df[skewed_features[i]])
        ax.legend(["Skewness: {:.2f}".format(df[skewed_features[i]].skew())], fontsize = 'xx-large')
# Out:
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
SalePrice = np.log(train['SalePrice'] + 1)

# %%
# get object feature to conver in numeric using dummy variable
obj_feat = list(df.loc[:,df.dtypes == 'object'].columns.values)
len(obj_feat)
# Out:
# 29

# %%
# dummy varaibale
dummy_drop = []
clean_df = df
for i in obj_feat:
    dummy_drop += [i + '_' + str(df[i].unique()[-1])]

df = pd.get_dummies(df, columns = obj_feat)
df = df.drop(dummy_drop, axis = 1)

# %%
df.shape
# Out:
# (1460, 488)

# %%
#sns.pairplot(df)

# %%
# scaling dataset with robust scaler
from sklearn.preprocessing import RobustScaler
scaler = RobustScaler()
scaler.fit(df)
df = scaler.transform(df)

# %% [markdown]
# ## Machine Learning Model Building

# %%
train_len = len(train)

# %%
X_train = df[:train_len]
X_test = df[train_len:]
y_train = SalePrice

print(X_train.shape)
print(X_test.shape)
print(len(y_train))
# Out:
# (1168, 488)
# (292, 488)
# 1168

# %% [markdown]
# ## Cross Validation

# %%
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import make_scorer, r2_score

def test_model(model, X_train=X_train, y_train=y_train):
    cv = KFold(n_splits = 3, shuffle=True, random_state = 45)
    r2 = make_scorer(r2_score)
    r2_val_score = cross_val_score(model, X_train, y_train, cv=cv, scoring = r2)
    score = [r2_val_score.mean()]
    return score

# %% [markdown]
# ## Linear Regression

# %%
import sklearn.linear_model as linear_model
LR = linear_model.LinearRegression()
test_model(LR)
# Out:
# [-3.5655995736434102e+19]

# %%
import sklearn.linear_model as linear_model
LR = linear_model.LinearRegression()
test_model(LR)
# Out:
# [-3.5655995736434102e+19]

# %%
rdg = linear_model.Ridge()
test_model(rdg)
# Out:
# [0.9432638092205009]

# %%
lasso = linear_model.Lasso(alpha=1e-4)
test_model(lasso)
# Out:
# [0.9482153723361536]

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn.svm import SVR
svr_reg = SVR(kernel='rbf')
test_model(svr_reg)
# Out:
# [0.8766391199451175]

# %% [markdown]
# # Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
dt_reg = DecisionTreeRegressor(random_state=21)
test_model(dt_reg)
# Out:
# [0.995930917072307]

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
rf_reg = RandomForestRegressor(n_estimators = 1000, random_state=51)
test_model(rf_reg)
# Out:
# [0.997823404800687]

# %% [markdown]
# # Bagging & Boosting

# %%
from sklearn.ensemble import BaggingRegressor, GradientBoostingRegressor
br_reg = BaggingRegressor(n_estimators=1000, random_state=51)
gbr_reg = GradientBoostingRegressor(n_estimators=1000, learning_rate=0.1, loss='ls', random_state=51)

# %%
test_model(br_reg)
# Out:
# [0.9977595543472804]

# %%
test_model(gbr_reg)
# Out:
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\sklearn\ensemble\_gb.py:286: FutureWarning: The loss 'ls' was deprecated in v1.0 and will be removed in version 1.2. Use 'squared_error' which is equivalent.
#   warnings.warn(
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\sklearn\ensemble\_gb.py:286: FutureWarning: The loss 'ls' was deprecated in v1.0 and will be removed in version 1.2. Use 'squared_error' which is equivalent.
#   warnings.warn(
# C:\Users\Visual singh\anaconda3\anaconda file\lib\site-packages\sklearn\ensemble\_gb.py:286: FutureWarning: The loss 'ls' was deprecated in v1.0 and will be removed in version 1.2. Use 'squared_error' which is equivalent.
#   warnings.warn(
# [0.999549387893342]

# %% [markdown]
# # XGBoost

# %%
import xgboost
#xgb_reg=xgboost.XGBRegressor()
xgb_reg = xgboost.XGBRegressor(bbooster='gbtree', random_state=51)
test_model(xgb_reg)
# Out:
# [00:37:51] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "bbooster" } are not used.
#
# [00:37:52] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "bbooster" } are not used.
#
# [00:37:53] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "bbooster" } are not used.
# [0.9982021548982257]

# %% [markdown]
# # SVM Model Bulding

# %%
svr_reg.fit(X_train,y_train)
y_pred = np.exp(svr_reg.predict(X_test)).round(2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [110], in <cell line: 2>()
#       1 svr_reg.fit(X_train,y_train)
# ----> 2 y_pred = np.exp(svr_reg.predict(X_test)).round(2)
#
# File ~\anaconda3\anaconda file\lib\site-packages\sklearn\svm\_base.py:414, in BaseLibSVM.predict(self, X)
#     398 def predict(self, X):
#     399     """Perform regression on samples in X.
#     400
#     401     For an one-class model, +1 (inlier) or -1 (outlier) is returned.
#    (...)
#     412         The predicted values.
#     413     """
# --> 414     X = self._validate_for_predict(X)
#     415     predict = self._sparse_predict if self._sparse else self._dense_predict
#     416     return predict(X)
#
# File ~\anaconda3\anaconda file\lib\site-packages\sklearn\svm\_base.py:592, in BaseLibSVM._validate_for_predict(self, X)
#     589 check_is_fitted(self)
#     591 if not callable(self.kernel):
# --> 592     X = self._validate_data(
#     593         X,
#     594         accept_sparse="csr",
#     595         dtype=np.float64,
#     596         order="C",
#     597         accept_large_sparse=False,
#     598         reset=False,
#     599     )
#     601 if self._sparse and not sp.isspmatrix(X):
#     602     X = sp.csr_matrix(X)
#
# File ~\anaconda3\anaconda file\lib\site-packages\sklearn\base.py:566, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     564     raise ValueError("Validation should be done on X, y or both.")
#     565 elif not no_val_X and no_val_y:
# --> 566     X = check_array(X, **check_params)
#     567     out = X
#     568 elif no_val_X and not no_val_y:
#
# File ~\anaconda3\anaconda file\lib\site-packages\sklearn\utils\validation.py:800, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     794         raise ValueError(
#     795             "Found array with dim %d. %s expected <= 2."
#     796             % (array.ndim, estimator_name)
#     797         )
#     799     if force_all_finite:
# --> 800         _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#     802 if ensure_min_samples > 0:
#     803     n_samples = _num_samples(array)
#
# File ~\anaconda3\anaconda file\lib\site-packages\sklearn\utils\validation.py:114, in _assert_all_finite(X, allow_nan, msg_dtype)
#     107     if (
#     108         allow_nan
#     109         and np.isinf(X).any()
#     110         or not allow_nan
#     111         and not np.isfinite(X).all()
#     112     ):
#     113         type_err = "infinity" if allow_nan else "NaN, infinity"
# --> 114         raise ValueError(
#     115             msg_err.format(
#     116                 type_err, msg_dtype if msg_dtype is not None else X.dtype
#     117             )
#     118         )
#     119 # for object dtype data, we only check for NaNs (GH-13254)
#     120 elif X.dtype == np.dtype("object") and not allow_nan:
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
